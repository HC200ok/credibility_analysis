# %%
import evolution
import pandas as pd
import MeCab
import numpy as np

df = pd.read_csv("../data/fixed_data.csv")
df['day_fixed'] = pd.to_datetime(df['day_fixed'])

tagger = MeCab.Tagger("-Owakati")

def data_define(d, tokenize=tagger.parse, c1="title", c2="body", sep="。", size=1):
    return tokenize('。'.join([d[1][c1]] + d[1][c2].split(sep)[:size]))

df['data'] = list(map(data_define, df.iterrows()))
df = df[['title', 'data', 'day_fixed']].sort_values(by="day_fixed")
word_vectors = evolution.texts_encoder(df['data'].tolist())
chains, instances = evolution.execute(df, word_vectors, size=5000, chain_threshold=0.85, regrouping_level=0)
len(instances)
# Out:
# INFO:tensorflow:Initialize variable module/embeddings/part_0:0 from checkpoint b'/tmp/tfhub_modules/f2587ea6ed3c5c0de24d63525ca949545fc6de9e/variables/variables' with embeddings
# 0.0
# /root/work/detect_fakenews_jp/notebook/event_evolution_chain_notebook/evolution_fix.py:69: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   len_data = df[today <= df[day_column]][df[day_column] <= after_week].shape[0]
# 2.567855583801967
# 5.135711167603934
# 7.7035667514059005
# 10.271422335207868
# 4800

# %%
regrouped_instances = evolution.regrouping(instances, word_vectors, threshold=0.89)

# %%
for i, e in enumerate(regrouped_instances):
    if df.iloc[e].shape[0] > 1:
        print("[event {}]".format(i))
        print(df.iloc[e].sort_values(by="day_fixed").drop_duplicates()['title'])
        print()
# Out:
# [event 2]
# 17041      「日韓の米軍撤退させ核配備を」、トランプ発言に両国が反論
# 16894                 トランプ氏の外交政策、ロシアで好評
# 15505          中国、「一つの中国」めぐるトランプ氏の発言に反発
# 15434        メイ英首相「米と世界を主導」 トランプ氏との会談前に
# 37010    米上院議員、トランプ氏に武力支援を訴え ウクライナ情勢悪化で
# 11235         対ロ制裁「クリミア返還まで維持」 米国連大使が明言
# 36971    米国防長官、中国の南シナ海での活動を批判 劇的な軍展開は不要
# 15389           中国、批判の声明 米国防長官の「尖閣防衛」宣言
# 11198       中国、マティス米国防長官の「尖閣は日米安保範囲」に警告
# Name: title, dtype: object
#
# [event 7]
# 17026    米軍、シナイ半島北部基地からの撤退を検討 ＩＳＩＳの脅威増大で
# 16840        内戦のイエメンに米軍要員、アルカイダ系組織の掃討を支援
# 16462       トルコの米軍基地が閉鎖、空爆も中止 対ＩＳＩＳ作戦の拠点
# 15991       イラク軍、モスルの奪還作戦を開始 ＩＳＩＳの国内最大拠点
# 15993      モスル奪還作戦にＩＳＩＳも準備 油井に火、トンネル網を整備
# 16001         モスル奪還作戦 ９つの村を制圧、主要道路の一部も確保
# 15673       アレッポ、政府軍攻勢で市民の殺害報告相次ぐ 決死の避難も
# 15328       米国防総省、シリアへの地上部隊派遣を提案か 当局者が示唆
# Name: title, dtype: object
#
# [event 11]
# 17040      不明マレーシア機か、モーリシャスで新たに残骸発見
# 16157    不明マレーシア機の新たな残骸か、機内で火災の可能性も
# Name: title, dtype: object
#
# [event 19]
# 17031    租税回避地めぐる「パナマ文書」が流出、世界の指導者らの名前も
# 17032          アイスランド首相が辞任 「パナマ文書」で批判浴び
# Name: title, dtype: object
#
# [event 23]
# 16998          インドの寺院で火災、死者７５人 花火が原因か
# 17004     インドの寺院火災、死者１０５人に 警察が事件として捜査
# 16354    病院で自爆テロ、７０人死亡 弁護士や記者狙う パキスタン
# Name: title, dtype: object
#
# [event 28]
# 17033    北朝鮮、核弾頭の小型化に成功か 韓国当局が分析
# 12212    北朝鮮の核兵器「発射可能も標的狙えず」 米高官
# 15716      北朝鮮、「核兵器運搬能力を保持」 米軍高官
# Name: title, dtype: object
#
# [event 37]
# 17019       ＩＳＩＳ、工場作業員３００人あまりを拉致か シリア
# 17017    ＩＳＩＳが拉致した工場作業員３００人、解放の報道 シリア
# Name: title, dtype: object
#
# [event 48]
# 16993    無人島で海難の３人救出、砂浜にヤシの葉でＳＯＳ 西太平洋
# 16849          太平洋を２カ月漂流の男性救助、仲間３人は死亡
# Name: title, dtype: object
#
# [event 53]
# 16992      武装勢力が軍兵士２８人殺害、停戦発効直前に イエメン
# 16427     アフガン首都で自爆テロ、８０人死亡 ＩＳＩＳが犯行声明
# 16255    イエメン軍施設に自爆テロ、１００人超死傷 ＩＳＩＳが声明
# Name: title, dtype: object
#
# [event 60]
# 16997              北朝鮮の情報機関幹部、韓国に亡命
# 16991    情報機関高官ら相次ぐ脱北 北朝鮮は「ギャング」と非難
# Name: title, dtype: object
#
# [event 62]
# 16990    ブラジル下院特別委、ルセフ大統領への弾劾手続き承認
# 16953    ブラジル下院、大統領の弾劾決議を承認 上院で審議へ
# 16812         ブラジル上院、大統領弾劾の是非問う投票へ
# 16336       ブラジル上院、ルセフ大統領の弾劾手続きを承認
# Name: title, dtype: object
#
# [event 69]
# 16986            台湾籍の４５人、ケニアから中国に「強制連行」
# 16967    ケニアから中国に強制移送の台湾籍２人、国営メディアで「謝罪」
# Name: title, dtype: object
#
# [event 74]
# 16984    ロシア軍機、米軍艦に異常接近 「機銃掃射」態勢で飛行
# 16949    ロシア軍機、今度は米軍偵察機に異常接近 バルト海上空
# 16883             ロシア軍機、またも米軍機に異常接近
# Name: title, dtype: object
#
# [event 78]
# 16976    熊本地震、死者９人に さらなる倒壊の恐れも
# 16968       熊本でＭ７の地震、７人死亡 建物倒壊
# 16952          熊本で相次ぐ地震、死者３２人に
# Name: title, dtype: object
#
# [event 79]
# 16961    熊本地震 死者４１人に 米軍の支援受け入れへ
# 16960       熊本地震の死者４２人に １８万人が避難
# Name: title, dtype: object
#
# [event 80]
# 16971       北朝鮮、ミサイル発射も失敗か 韓国軍が声明
# 16901    北朝鮮がまた中距離ミサイル発射、失敗 韓国国防省
# 16709      北朝鮮、ムスダン発射を試み失敗か 韓国軍発表
# 16387         北朝鮮が弾道ミサイルを発射 韓国軍発表
# Name: title, dtype: object
#
# [event 85]
# 16963          「パナマ文書」流出問題、プーチン大統領「米国が関与」
# 16950          サウジ、同時テロめぐる法案で米に警告 経済報復を示唆
# 16938               英王冠の巨大ダイヤ、インド政府が返還求める
# 38792    領土問題ある島々への日本人訪問、規制緩和する可能性＝ロシア大統領
# 38211    米情報長官、ロシアのサイバー攻撃を「確信」 トランプ氏の姿勢批判
# 38150        米選挙戦中のサイバー攻撃、トランプ氏がロシアの関与認める
# Name: title, dtype: object
#
# [event 89]
# 16974            ロシア、新型潜水艦を積極配備 冷戦後最大の攻勢
# 15659         中国艦船、米海軍の無人潜水機奪う 国防総省が返還要求
# 12052          中国、南シナ海で米潜水機を「違法に奪取」 国防総省
# 12046      中国、米海軍の無人潜水機返還へ 米の「大げさな」対応を批判
# 15653       米無人潜水機、中国が返還に同意 トランプ氏は盗んだと非難
# 38748                     中国、米無人潜水機返還に同意
# 38728      中国、無人潜水機は米軍の偵察活動の一部と認識 返還で落着へ
# 38726          中国外務省「事態は適切に処理」、米無人潜水機拿捕で
# 15655       米無人潜水機戻らず 中国はトランプ氏の「盗み」発言に反発
# 38690    米無人潜水機、20日にも南シナ海上で中国が返還か＝米政府関係者
# 11999               中国、南シナ海で奪った米無人潜水機を返還
# Name: title, dtype: object
#
# [event 103]
# 16942    自爆テロで死傷者、タリバーンが犯行声明 アフガン首都
# 16935            アフガン首都の自爆テロ、死者６４人に
# 16382      アフガン首都のホテルで爆発、タリバーンが犯行声明
# Name: title, dtype: object
#
# [event 104]
# 16945         アフガン首都で自爆テロ ２８人死亡、３００人超負傷
# 16797              バグダッドでまた爆弾テロ、警官１３人死傷
# 16485       カシミール地方で衝突、２０人死亡 武装組織の幹部殺害で
# 16207    アフガン首都で相次ぐ爆発、死傷者１００人超 タリバーンが声明
# 15965         パキスタンの警察学校に襲撃 ２０人死亡、６０人負傷
# 15966            警察学校に襲撃、死傷者１６２人に パキスタン
# 15952     警察学校襲撃の死者６１人に、ＩＳＩＳが犯行声明 パキスタン
# Name: title, dtype: object
#
# [event 106]
# 16936    モザンビークの残骸、マレーシア機と「ほぼ断定」 豪当局
# 16806    アフリカで発見の残骸、不明マレーシア機の部品とほぼ断定
# Name: title, dtype: object
#
# [event 112]
# 16924    英エリザベス女王、９０歳に ウィリアム王子が思い語る
# 16931       エリザベス女王９０歳に、議会も国民も祝賀ムード
# Name: title, dtype: object
#
# [event 114]
# 16920      パキスタンでまたポリオ接種阻止の攻撃、警官７人殺害
# 16687    警察幹部の妻が惨殺、テロ対策への報復か バングラデシュ
# 16552          バングラ・カフェ襲撃、警察が複数の人質救出
# Name: title, dtype: object
#
# [event 121]
# 16922    ベルギー自爆犯、ＩＳＩＳ人質の「看守」だった 元人質が証言
# 16913            フィリピン過激派、人質のカナダ人男性を殺害
# Name: title, dtype: object
#
# [event 124]
# 16928          北朝鮮、潜水艦ミサイルを発射か 飛距離３０キロ
# 16521        北朝鮮、潜水艦弾道ミサイル発射か 飛行失敗の可能性
# 16289    北朝鮮、日本海から潜水艦弾道ミサイル発射 ５００キロ飛行か
# 16200            北朝鮮、弾道ミサイル３発発射 日本海に向け
# 15352            北朝鮮、弾道ミサイルを発射 ５００キロ飛行
# Name: title, dtype: object
#
# [event 132]
# 16906     テロ被害の地下鉄駅が再開、掲示板に追悼の言葉 ベルギー
# 16872    テロ発生の出発ロビー、１カ月半ぶり再開 ブリュッセル空港
# Name: title, dtype: object
#
# [event 137]
# 16895     米軍、ＩＳＩＳ空爆で民間人に事前警告 イスラエルに倣い
# 15399    イエメンの米軍作戦、民間人の犠牲多数で反米感情強まる恐れ
# Name: title, dtype: object
#
# [event 141]
# 16890    北朝鮮、来月６日に党大会 ３６年ぶり開催
# 16847         北朝鮮が３６年ぶりに党大会開催
# Name: title, dtype: object
#
# [event 161]
# 16859      イラク南部で連続自爆テロ、１１人死亡 ＩＳＩＳが犯行声明
# 16825       バグダッドで爆弾テロ、１５１人死傷 ＩＳＩＳが犯行声明
# 16797              バグダッドでまた爆弾テロ、警官１３人死傷
# 16435      バグダッドでまた自爆テロ、２１人死亡 ＩＳＩＳが犯行声明
# 16175    バグダッドで車爆弾による攻撃、１１人死亡 ＩＳＩＳが犯行声明
# Name: title, dtype: object
#
# [event 165]
# 16867      米特殊部隊員１人死亡、ＩＳＩＳが拠点襲撃 イラク北部
# 16010    ＩＳＩＳのドローンが爆発、クルド兵ら４人死傷 イラク北部
# 15861     ＩＳＩＳが民間人６０人を殺害、市内に遺体つるす モスル
# Name: title, dtype: object
#
# [event 166]
# 16866         難民収容施設で相次ぐ焼身、豪政府の政策に批判
# 15597    難民が死亡、豪政府の責任問う声 過酷な収容政策の犠牲か
# Name: title, dtype: object
#
# [event 169]
# 16787     ＬＧＢＴ活動家殺害、過激派１人を逮捕 バングラデシュ
# 11603         ダッカ飲食店襲撃事件、新たに首謀者1人を逮捕
# 15495    ダッカ襲撃の首謀者か、過激派幹部を逮捕 バングラデシュ
# 37794     イスタンブールの銃乱射事件、容疑者の男拘束＝メディア
# 11554      イスタンブール銃乱射事件、実行犯拘束 逃走2週間余
# 11564     イスタンブール銃乱射事件、拘束された容疑者が犯行自供
# Name: title, dtype: object
#
# [event 170]
# 16865        激戦地アレッポで停戦発効、米ロ合意受け シリア
# 16634          アレッポで４８時間の停戦を確保、米ロが発表
# 16163    シリア停戦発効、直後に攻撃報告 活動家「楽観できない」
# 15578         ロシア、シリア停戦合意を発表 和平協議入りも
# 11851          シリア停戦、おおむね順守 首都近郊で戦闘も
# Name: title, dtype: object
#
# [event 184]
# 16818       ムスリムの新ロンドン市長、トランプ氏の「例外」発言を一蹴
# 16596       トランプ氏「次は米国」 大統領選でも反エリート感情が鍵か
# 37292    独首相「テロ対策は入国制限の理由にならず」、米大統領との電話で
# 37273             難民・移民制限の米大統領令、共和党からも批判
# 37223    入国制限の大統領令を擁護せず、合法との確信ない＝米司法長官代行
# 15427      トランプ米大統領の入国禁止措置、欧州の同盟国からも非難の声
# 15403             欧州の極右勢力からは歓迎の声 米入国禁止措置
# 11276     米入国禁止令に航空業界も混乱、トランプ政権に「明確な説明を」
# 15411       仏極右政党のルペン党首、トランプ氏による入国禁止令を称賛
# 37030      米マイクロソフト、移民入国制限に例外措置を要請 個々に判断
# Name: title, dtype: object
#
# [event 201]
# 16836    大統領弾劾手続き、下院議長代行が採決無効を主張 ブラジル
# 16804     ブラジル、弾劾裁判開始へ ルセフ氏「クーデター」と反発
# Name: title, dtype: object
#
# [event 204]
# 16827        米国防総省、ＩＳＩＳ幹部殺害を発表 イラク西部
# 16499    イラク軍、ＩＳＩＳから空軍基地を奪還 モスル解放へ前進
# 16378              米、リビアでＩＳＩＳ拠点の空爆開始
# 16142    米国防総省、ＩＳＩＳ「情報相」殺害を発表 無人機攻撃で
# Name: title, dtype: object
#
# [event 208]
# 16826     比新大統領のドゥテルテ氏、悪に対しては「独裁者に」
# 16703      腐敗した記者の殺害を正当化、フィリピン次期大統領
# 16679    比新大統領、今度は殺人を「許可」 犯罪者が抵抗すれば
# Name: title, dtype: object
#
# [event 219]
# 16805    ロシア軍、シリア国内で変わらず存在感 ヘリ・戦闘機が展開
# 16303       ロシア爆撃機、イラン基地から初の出撃 シリア空爆で
# 16316     シリア軍機、米軍部隊拠点近くを空爆 両軍戦闘機の遭遇も
# 16117       人道支援車列に空爆、米政府「ロシアに責任」 シリア
# 16109       ロシア、シリア沖へ空母派遣 国連では米ロ外相が応酬
# 16102          イラクでＩＳＩＳの船舶への攻撃加速 米軍など
# Name: title, dtype: object
#
# [event 220]
# 16744      クルド人部隊、ラッカ奪還へ軍事作戦 ＩＳＩＳ「首都」
# 16342    クルド人部隊、シリア北部マンビジュを奪還 住民が解放喜ぶ
# 16328      ＩＳＩＳ、民間人を「人間の盾」か シリア北部から敗走
# 16270     トルコ軍戦車、シリアに越境 ＩＳＩＳ掃討で反体制派支援
# 15896       モスル奪還作戦、市東部で激戦 ＩＳＩＳが激しい抵抗
# 15867       対ＩＳＩＳ、「首都」ラッカでも奪還作戦開始 シリア
# 15843              イラク軍、モスル近郊の古代遺跡を奪還
# Name: title, dtype: object
#
# [event 231]
# 16784     ガス工場襲撃で１０人死亡、ＩＳＩＳが犯行声明 イラク
# 16551    ダッカ襲撃 ＩＳＩＳが犯行声明、事件画像をネットに投稿
# 16534            ダッカ襲撃事件、国内の武装勢力が関与か
# 15649      イエメン自爆テロ、死者５２人に ＩＳＩＳが犯行声明
# Name: title, dtype: object
#
# [event 236]
# 16789            バグダッドで爆弾テロ続発、４６人死亡
# 16554    バグダッドで爆弾テロ、１２人死亡 ＩＳＩＳが犯行声明
# Name: title, dtype: object
#
# [event 237]
# 16756    シリアとイエメンで連続テロ、死者１２０人超 ＩＳＩＳが声明
# 15463      パキスタンで爆弾テロ、２０人死亡 反政府勢力が犯行声明
# 15450      ソマリア首都で連続爆発、１０人死亡 シャバブが犯行声明
# Name: title, dtype: object
#
# [event 242]
# 16785     ２年前に集団拉致された女子生徒、１人を保護 ナイジェリア
# 16770          ボコ・ハラム集団拉致、新たに女子生徒１人を救出
# 16324     拉致した女生徒の映像公開、戦闘員の釈放要求 ナイジェリア
# 16000    解放された女性が家族に再会、依然１９７人不明 ナイジェリア
# Name: title, dtype: object
#
# [event 244]
# 16790          中国軍機、米偵察機に異常接近 南シナ海上空
# 16675    米偵察機、中国軍機から「危険な飛行妨害」 東シナ海上空
# 16573        米軍Ａ１０、高速道路で着陸訓練 ロシア国境近く
# 16185          ロシア戦闘機、米軍機に３メートルの異常接近
# 15940                米ロ軍機がシリア上空でニアミス
# Name: title, dtype: object
#
# [event 251]
# 16776     消息不明のエジプト機、救難信号出ていた ６６人が搭乗
# 16769       消息不明のエジプト機、救難信号は船舶からの可能性
# 16778     残骸違った、不明エジプト機の捜索続く テロの可能性も
# 16777    不明エジプト機、海上で残骸見つかる 捜索・回収作業進む
# 16767            エジプト機墜落 直前に機内で煙を探知か
# Name: title, dtype: object
#
# [event 252]
# 16731    墜落のエジプト機から救難信号 捜索範囲半径５キロ以内に
# 16641    エジプト機墜落 残骸を発見、レコーダー類は引き続き捜索
# Name: title, dtype: object
#
# [event 259]
# 16757           タリバーン最高指導者、米軍の空爆で死亡か
# 15404    アルカイダ系指導者の８歳娘死亡か、イエメンの米軍作戦で
# Name: title, dtype: object
#
# [event 263]
# 16765    イラク、ファルージャ解放作戦開始を宣言 住民に退避要請
# 15796     イラク軍、モスルを完全包囲 ＩＳＩＳの補給ルート断つ
# Name: title, dtype: object
#
# [event 264]
# 16743    イラクのファルージャ奪還作戦、１万世帯が立ち往生か
# 16697       ファルージャ奪還作戦、ＩＳＩＳの抵抗で激戦に
# 16699    ファルージャ攻防戦、市内の子ども２万人動けず 国連
# Name: title, dtype: object
#
# [event 265]
# 16727               イラク軍、ファルージャ近郊の要衝を奪還
# 16631             イラク当局、ファルージャ中心部の奪還を発表
# 16575          イラク軍、ファルージャ奪還を宣言 市民の窮状続く
# 16300        対ＩＳＩＳ、モスル奪還の決戦迫る イラク軍を現地取材
# 15919            市内への進攻は「時間の問題」 モスル奪還作戦
# 15843                イラク軍、モスル近郊の古代遺跡を奪還
# 12316    シリア軍、アレッポ東部の半分を奪還 市街戦のため精鋭部隊到着
# 15718          リビア部隊、中部シルトのＩＳＩＳ支配地を全て奪還
# 37688       イラク軍、モスル東部の解放を宣言 西部は依然ＩＳが支配
# 15453             イラク部隊、モスル東半分を奪還 首相が発表
# Name: title, dtype: object
#
# [event 266]
# 16720    クルド人部隊、イラク北部で奪還作戦 兵士５５００人を投入
# 15957         モスル奪還作戦、クルド人部隊が８キロ以内に迫る
# 15863    ＩＳＩＳ高位司令官、空爆で死亡 フセイン時の情報機関幹部
# 15861     ＩＳＩＳが民間人６０人を殺害、市内に遺体つるす モスル
# 15593         モスル奪還作戦続く、ＩＳＩＳ戦闘員９７人を殺害
# Name: title, dtype: object
#
# [event 267]
# 16719    イラク軍、ファルージャ中心部へ進撃開始 住民巻き込む恐れ
# 16690    ファルージャ奪還、イラク軍攻勢 ＩＳＩＳ「首都」にも攻撃
# Name: title, dtype: object
#
# [event 271]
# 16752    エジプト機捜索に潜水艦出動、墜落原因「まだ判断できず」
# 16750     エジプト機の捜索続く 墜落直前の状況説明に食い違いも
# Name: title, dtype: object
#
# [event 278]
# 16746       オーストリア大統領選 極右候補が接戦の末に敗北
# 12301        オーストリア大統領選、反移民の極右候補が敗北
# 15744          オーストリア大統領選、極右候補が敗北宣言
# 15737    オーストリア大統領選、リベラル派勝利で「欧州が安堵」
# Name: title, dtype: object
#
# [event 282]
# 16747     タリバーン、新指導者を発表 マンスール幹部の殺害確認
# 16728    アフガン政府との和平協議「しない」 タリバーン新指導者
# 16661       アルカイダ最高指導者、タリバーン新指導者に忠誠か
# Name: title, dtype: object
#
# [event 283]
# 16739       オバマ大統領、沖縄遺棄事件で謝罪 日米首脳会談
# 16198    オバマ米大統領、フィリピン大統領の暴言受け会談を中止
# 16203     フィリピン大統領、オバマ米大統領への発言で遺憾表明
# Name: title, dtype: object
#
# [event 284]
# 16741    伊軍艦の目前で船が転覆、５人死亡 難民５００人を救助
# 16729      難民船、地中海での転覆相次ぐ 死者７００人以上か
# Name: title, dtype: object
#
# [event 289]
# 16724      オバマ米大統領、広島へ 核兵器の脅威訴える機会に
# 16733    オバマ米大統領、広島を訪問 「核兵器のない世界」訴え
# Name: title, dtype: object
#
# [event 301]
# 16712    女性がワニに襲われ行方不明、議員はワニを「擁護」 豪
# 16669      ダイビングの女性死亡、サメの襲撃相次ぐ 豪州西部
# Name: title, dtype: object
#
# [event 302]
# 16649          密航仕掛けた容疑で逮捕の男、友人ら「人違い」と主張
# 16361             刃物男が警官襲撃、テロの疑いで捜査 ベルギー
# 16319        スイスの列車襲撃、容疑者の男が死亡 テロとの関連なしか
# 12222              フィリピン当局「警察が無防備の町長を殺害」
# 12181    コロンビア墜落、直前に予備燃料の問題報告 ボリビア当局が隠蔽か
# 11871     独トラック突入、チュニジア国籍の男を拘束 容疑者とつながりか
# 11861     独トラック突入、共犯疑いの男性釈放 犯人、直前に「万事順調」
# 15562         トルコ銃乱射 容疑者の指紋や人相判明、８人の身柄拘束
# 11773    移民男性に嫉妬…偽の「テロリスト」通報で男を逮捕 オーストリア
# 11283        黒崎さん不明事件、仏がチリに容疑者の拘束・引き渡し要請
# 11252    独で逮捕されたチュニジア人の男、2015年の博物館襲撃に関与か
# 11149    偽ニュース拡散でFBを提訴、シリア難民が起こした裁判始まる 独
# Name: title, dtype: object
#
# [event 309]
# 16707          病院などに爆撃、２３人死亡 シリア北西部
# 16060    クルドの結婚式場で自爆テロ、２２人死亡 シリア北東部
# Name: title, dtype: object
#
# [event 317]
# 16690    ファルージャ奪還、イラク軍攻勢 ＩＳＩＳ「首都」にも攻撃
# 16668             イラク軍、ファルージャの一部地域を奪還
# 16655      ＩＳＩＳ、リビアでも支配地失う 政府軍がシルトを奪還
# 15536    モスル奪還作戦 イラク軍、市中流れるチグリス川東岸に到達
# 11703    モスル奪還戦、イラク軍がチグリス川沿岸に到達 ISに圧力
# Name: title, dtype: object
#
# [event 318]
# 16705      男らが１８歳女性焼き殺す、結婚断られ パキスタン
# 16647    母親らが１８歳娘焼き殺す、結婚相手に反対 パキスタン
# Name: title, dtype: object
#
# [event 326]
# 16660     汚職捜査に大活躍の日系人警官、密輸関与で逮捕 ブラジル
# 15415    フィリピン大統領、警察組織の「浄化」命じる 韓国人殺害で
# Name: title, dtype: object
#
# [event 343]
# 16650      ２日間で５千人逮捕、過激派取り締まり バングラデシュ
# 16645    バングラデシュ、過激派取り締まり続く ３日間で８千人逮捕
# 16642     過激派取り締まりで１万１千人逮捕、野党は反発 バングラ
# Name: title, dtype: object
#
# [event 359]
# 16658        強姦被害のオランダ人女性を拘束、姦通罪適用か カタール
# 16639    強姦被害訴えたオランダ人女性、「不法な性行為」で有罪 カタール
# Name: title, dtype: object
#
# [event 360]
# 16632        フィリピン過激派、カナダ人人質の２人目を殺害
# 16216    フィリピン爆発 男女３人の行方追う、イスラム過激派か
# Name: title, dtype: object
#
# [event 363]
# 16636            パリの警官刺殺、襲撃の様子を生中継 仏情報筋
# 12004       ベルリンのトラック突入、拘束されたのは亡命希望者の男性
# 11995     トラック突入のベルリン、市内観光客「思うつぼにはならない」
# 11861    独トラック突入、共犯疑いの男性釈放 犯人、直前に「万事順調」
# Name: title, dtype: object
#
# [event 369]
# 16617    墜落したエジプト機のボイスレコーダー、損傷した状態で発見
# 16608         エジプト航空機のブラックボックス、修復作業続く
# Name: title, dtype: object
#
# [event 372]
# 16621    英議員殺害で男を訴追、「理想的な隣人」の犯行に周囲驚き
# 38657      トラック突入の容疑者釈放、証拠不十分で＝ドイツ検察
# Name: title, dtype: object
#
# [event 376]
# 16584               外交官への嫌がらせ頻発、米ロが批判の応酬
# 16506              米国とロシア、相互の外交官を国外退去処分に
# 16464        トルコ、米にイスラム教指導者の拘束要求 本人は関与否定
# 16443      ギュレン師の引き渡し、トルコが米に正式要求 「テロ指導者」
# 15997        米英、ロシアとシリアに経済制裁を検討 アレッポ空爆受け
# 38638    シリアめぐる3か国会議、米国の不参加は影響力低下示さず＝国務省
# 11840    ロ外相、 米への報復で外交官35人の追放をプーチン大統領に要請
# 15515        「サイバー介入」の米報告書、ロシアが「事実無根」と一蹴
# Name: title, dtype: object
#
# [event 380]
# 16592           英国民投票、「離脱」勝利か ＢＢＣなど報道
# 16595           英国民投票、ＥＵからの「離脱」派が勝利確実
# 16591         キャメロン英首相、辞意表明 ＥＵ離脱派勝利受け
# 16598          英連合に危機、スコットランドで独立の機運再び
# 16579    再投票の請願 発起人が「乗っ取られた」と当惑、実は離脱派
# 16580     英国のＥＵ離脱、交渉開始時期めぐり首脳間に意見の隔たり
# Name: title, dtype: object
#
# [event 387]
# 16624    リオ観光客の指定病院で襲撃事件、１人死亡 ２人負傷
# 16552        バングラ・カフェ襲撃、警察が複数の人質救出
# Name: title, dtype: object
#
# [event 398]
# 16611    ＥＵ離脱か残留か、英国で国民投票 賛否は依然拮抗
# 16610          英国民投票始まる、ＥＵに残留か離脱か
# Name: title, dtype: object
#
# [event 399]
# 16614    コロンビア政府と左翼ゲリラ、停戦で合意 内戦終結へ筋道
# 16277        コロンビア政府と左翼ゲリラ、内戦終結で最終合意
# Name: title, dtype: object
#
# [event 402]
# 16597            英国民投票、「残留」が僅差でリード 開票進む
# 16600    英国民投票、「離脱」がわずかにリード 半数近い地区の開票終了
# Name: title, dtype: object
#
# [event 405]
# 16587    中国江蘇省で竜巻 ７８人死亡、５００人負傷
# 16590     中国竜巻の死者、９８人に 負傷者８００人
# Name: title, dtype: object
#
# [event 413]
# 16577        中国で観光バスが炎上 ３５人死亡、１１人負傷
# 16459    台湾で観光バス火災、２６人死亡 大部分は中国人観光客
# Name: title, dtype: object
#
# [event 419]
# 16563    ＥＵ、英に「移民」での例外認めず 単一市場残留に条件
# 15486     メイ英首相、ＥＵ離脱の計画を発表 単一市場から撤退
# 15488        貿易交渉や移民政策、ＥＵ離脱で目指す先は 英
# Name: title, dtype: object
#
# [event 423]
# 16558         米ロ軍艦、地中海で異常接近 互いに非難
# 16549    ロシア軍艦、地中海で米軍艦にまた接近 空母追跡か
# Name: title, dtype: object
#
# [event 430]
# 16568    トルコ空港テロ、実行犯はシリアから入国か 死者４４人に
# 16537     爆弾事件はＩＳＩＳ関与と断定、マレーシアでは初のテロ
# Name: title, dtype: object
#
# [event 431]
# 16569    バングラ首都でカフェ襲撃、約２０人人質 警官２人死亡 ＩＳＩＳが犯行声明
# 16552                   バングラ・カフェ襲撃、警察が複数の人質救出
# 16556            バングラ人質事件、部隊突入で１４人救出 実行犯６人を射殺
# 16546                  バングラ人質事件、部隊突入で収束 実行犯射殺
# 16548             ダッカ襲撃、人質２０人死亡 全員外国人 バングラ軍発表
# 16542                 ダッカ襲撃 人質２０人が死亡、邦人７人も犠牲に
# 16534                     ダッカ襲撃事件、国内の武装勢力が関与か
# Name: title, dtype: object
#
# [event 432]
# 16512     バングラデシュのモスクで発砲、警官１人死亡 １０人負傷
# 15814    アフガン首都のモスクで自爆テロ、百人死傷 ＩＳＩＳが声明
# 15793     ＩＳＩＳが爆弾テロ、イラン人巡礼者ら８０人死亡 イラク
# Name: title, dtype: object
#
# [event 436]
# 16543      対ＩＳＩＳ空爆は「落第」、改善必要 米軍幹部が辛口採点
# 16231    ＩＳＩＳ戦闘員、最高指導者の「死闘」命令を無視 米軍司令官
# Name: title, dtype: object
#
# [event 439]
# 16545          繁華街の自爆テロ、死者１２５人に バグダッド
# 16532    バグダッドテロ、死者２１５人 焼け焦げた遺体に家族ら衝撃
# Name: title, dtype: object
#
# [event 444]
# 16517          イラク中部でテロ、４０人死亡 シーア派の廟が標的に
# 12530    アフガン首都のシーア派モスクで自爆攻撃、27人死亡 ISが声明
# 15814       アフガン首都のモスクで自爆テロ、百人死傷 ＩＳＩＳが声明
# 12463     イラクで自爆攻撃、イラン人巡礼者ら70人死亡 ISが犯行声明
# Name: title, dtype: object
#
# [event 454]
# 16520    英調査委、イラク戦争参戦の判断批判 「外交努力、不十分」
# 16513    ブレア氏、「正しい判断だった」 調査委がイラク参戦批判も
# 16526     ブレア元英首相の責任問う声も 調査委がイラク参戦を検証
# Name: title, dtype: object
#
# [event 470]
# 16498      南スーダンの衝突再燃、激しい交戦で死者１５０人超か
# 16501        南スーダンで衝突、国連事務総長が撤収を呼びかけ
# 16495    南スーダン、大統領が停戦呼びかけ 米国など一部人員退避
# Name: title, dtype: object
#
# [event 471]
# 16481              トルコ軍反乱、首都の銃撃戦で警官ら４２人死亡
# 16477    トルコ大統領、クーデター鎮圧宣言 ６０人死亡か 逮捕者７００人超
# Name: title, dtype: object
#
# [event 473]
# 16511    バハマ外務省、米国への旅行者に注意喚起 黒人射殺など受け
# 16490       「黒人の命も大事」、米男性射殺への抗議 欧州に波及
# Name: title, dtype: object
#
# [event 474]
# 16505    トランプ氏の国境の壁、「建設費出さない」 メキシコ大統領 CNN EXCLUSIVE
# 37421                  メキシコ大統領、訪米中止を検討中 「国境の壁」建設指示で
# 37408                    メキシコ国境の壁、米下院は建設費承認へ＝ライアン議長
# 37398                           メキシコ大統領、国境の壁建設は「遺憾」
# 37378               メキシコ大統領の訪米不要、「壁」費用負担しなければ＝トランプ氏
# 15441                 メキシコ大統領、「壁の費用出さない」 移民の保護強化を指示
# 11371                         実現可能？ トランプ米大統領の「国境の壁」
# Name: title, dtype: object
#
# [event 481]
# 16489    仲裁裁判所、「中国の主権認めず」 南シナ海問題で
# 16488        中国、南シナ海上空の防空識別圏設定に言及
# 16439     中国で米製品の不買運動 南シナ海の仲裁判決受け
# 16390     南シナ海問題、中国は「不法侵入者」を訴追の姿勢
# Name: title, dtype: object
#
# [event 485]
# 16492    エジプト当局による「強制失踪」、数百人規模か 国際人権団体
# 16413     トルコ当局、拘束の兵士らに虐待や拷問か アムネスティ報告
# Name: title, dtype: object
#
# [event 488]
# 16469    イラン軍艦艇、米中央軍司令官乗る艦船に接近 ホルムズ海峡
# 16285      イラン軍艦艇、米駆逐艦を「高速で妨害」 ホルムズ海峡
# 16262           米哨戒艇、イラン艦艇に警告射撃 ペルシャ湾
# 16199          イラン艦艇がまた米軍艦に異常接近 ペルシャ湾
# 16031         イエメン沖の米軍艦船にミサイル攻撃 海面に着弾
# 16014    米軍、イエメンのレーダー破壊 駆逐艦への再度の攻撃に報復
# 15992          米駆逐艦が応戦、３度目のミサイル攻撃か 紅海
# Name: title, dtype: object
#
# [event 490]
# 16480    仏ニースでトラック暴走、７７人死亡、負傷者１００人強
# 16429    ドイツ南部で爆発 １人死亡、１０人負傷 地元メディア
# Name: title, dtype: object
#
# [event 492]
# 16479            仏ニースのトラック突っ込み 実行犯の身元特定
# 11861    独トラック突入、共犯疑いの男性釈放 犯人、直前に「万事順調」
# Name: title, dtype: object
#
# [event 494]
# 16449          ニースのトラック突入、数カ月前から計画 仏検察
# 38677    ドイツのトラック突入、12人死亡 警察は計画的犯行との見方
# Name: title, dtype: object
#
# [event 497]
# 16470     英外相起用のジョンソン氏、過去に国際上の問題発言連発
# 16441    英国のジョンソン新外相に鋭い質問 米国務長官と共同会見
# Name: title, dtype: object
#
# [event 498]
# 16467    ニース事件、死者８４人に フランス襲うテロの連鎖
# 16449     ニースのトラック突入、数カ月前から計画 仏検察
# Name: title, dtype: object
#
# [event 505]
# 16463                  トルコ大統領、死刑復活も排除せず クーデター未遂受け
# 16466    クーデター首謀者、「国民が死刑求める」 トルコ大統領 CNN EXCLUSIVE
# Name: title, dtype: object
#
# [event 506]
# 16461      ＩＳＩＳ、イラクやシリアでは「敗走状態」 米国務長官
# 15767    イラク、ＩＳＩＳ支配地域の「５５％を奪還」 ライス補佐官
# Name: title, dtype: object
#
# [event 511]
# 16453     おので乗客切りつけ、容疑者宅からＩＳＩＳの旗 ドイツ
# 16319    スイスの列車襲撃、容疑者の男が死亡 テロとの関連なしか
# 16041       独警察、シリア人の男を捜索 爆弾テロ計画の疑いで
# 16025    テロ計画容疑でシリア難民の男逮捕、ＩＳＩＳと関連か 独
# Name: title, dtype: object
#
# [event 517]
# 16389    反体制派が砲撃、住民３０人死亡か シリア北部アレッポ
# 15916     シリア・アレッポ、反体制派が攻勢 住民３８人死亡か
# Name: title, dtype: object
#
# [event 525]
# 16433    ドイツで銃乱射、９人死亡 自殺の１８歳少年の犯行か
# 16432        シリア人の男が自爆、１３人死傷 ドイツ南部
# Name: title, dtype: object
#
# [event 528]
# 16425              不明マレーシア機の捜索を一時中止へ
# 15628          不明マレーシア機 豪当局が別海域の捜索提案
# 12007        マレー機の墜落現場、現在の捜索海域外か 豪当局
# 11865    ロシア軍、墜落機調査で機器の異常を確認 「爆発はなし」
# 15485       不明マレーシア機、捜索打ち切り 家族から失望の声
# Name: title, dtype: object
#
# [event 530]
# 16396     シリア北部でトラック自爆、４８人死亡 ＩＳＩＳが声明
# 11717    シリア北部で爆弾積んだタンクローリーが爆発、48人死亡
# Name: title, dtype: object
#
# [event 532]
# 16431    トルコ、ギュレン師関連の施設２千箇所を閉鎖 側近を拘束
# 16055       トルコ、７月以降で警官１万２０００人を停職処分に
# Name: title, dtype: object
#
# [event 540]
# 16410     障害者施設で１９人刺殺、２０代男を逮捕 相模原
# 16417    障害者施設で１９人刺殺２６人負傷、男逮捕 相模原
# Name: title, dtype: object
#
# [event 552]
# 16395       シリア政府軍、アレッポ包囲で補給路遮断 住民襲う食料難
# 16399       シリアとロシア、包囲したアレッポに人道目的の回廊設置へ
# 16258           政府軍包囲のシリア首都近郊、住民や戦闘員が退避
# 16133        有志連合がシリア軍を空爆、兵士死亡 安保理が緊急会合
# 12210            シリア政府軍、アレッポで戦闘停止 住民避難へ
# 11947    次はイドリブか ―「野外刑務所」の恐怖におびえるシリア避難民
# Name: title, dtype: object
#
# [event 571]
# 16381        混乱続く南スーダン 住民６万人が国外避難、略奪も横行か
# 11565    イエメン内戦、民間人死者1万人に 停戦へ国連特使が大統領と協議
# Name: title, dtype: object
#
# [event 572]
# 16379      エミレーツ機が着陸時に出火、全員無事脱出 ドバイ空港
# 16371    エミレーツ機炎上で消防士１人死亡、乗客１３人軽傷 ドバイ
# Name: title, dtype: object
#
# [event 585]
# 16362    ＩＳＩＳが避難民３０００人拘束、１２人殺害か イラク北部
# 15946           ＩＳＩＳ、アフガンで住民３０人を拉致・殺害
# 15932     ＩＳＩＳ、モスル近郊で２３２人を「処刑」 数万人を拉致
# Name: title, dtype: object
#
# [event 598]
# 16358    男性が通過する列車に頭ぶつけ死亡、窓から身を乗り出す 英
# 16321     英警察追跡の車が事故、２人死傷 刑務所への密輸に関与か
# 16319     スイスの列車襲撃、容疑者の男が死亡 テロとの関連なしか
# Name: title, dtype: object
#
# [event 616]
# 16301      自爆テロ図った少年を拘束、ＩＳＩＳが洗脳 イラク北部
# 16297        イラクで自爆テロ未遂の少年、拘束現場の新たな映像
# 15864    モスル奪還作戦、警官姿の集団が住民殺害 アムネスティ報告
# Name: title, dtype: object
#
# [event 628]
# 16311                    北朝鮮の駐英公使が韓国に亡命
# 37822    韓国への亡命待つ北朝鮮外交官はまだいる━元公使＝聯合ニュース
# Name: title, dtype: object
#
# [event 630]
# 16307    トルコの警察署外で車爆弾が爆発、３人死亡 ４０人負傷
# 16268       検問所の爆発で警官８人死亡、４５人負傷 トルコ
# Name: title, dtype: object
#
# [event 634]
# 16305    空爆で負傷した少年の映像公開、「これがシリアの日常」
# 16315        アレッポ空爆、衝撃映像に映った少年の兄が死亡
# Name: title, dtype: object
#
# [event 635]
# 16313    ドイツ、顔覆うベール着用を一部禁止へ 「社会にそぐわず」
# 15410     オーストリア、顔覆うベールの着用禁止へ 政府が方針発表
# Name: title, dtype: object
#
# [event 636]
# 16312     結婚式場で爆発、死傷者１２４人 トルコ南東部
# 16299    トルコの結婚式場爆発、死者５１人 少年が自爆か
# Name: title, dtype: object
#
# [event 646]
# 16295          イタリア中部でＭ６．２の地震
# 16282    イタリア中部でＭ６．２の地震、建物が倒壊
# 16284     イタリア中部でＭ６．２の地震、２人死亡
# Name: title, dtype: object
#
# [event 649]
# 16280       トルコ軍、ＩＳＩＳ支配下の町を攻撃 シリア国境沿い
# 16270     トルコ軍戦車、シリアに越境 ＩＳＩＳ掃討で反体制派支援
# 16217    トルコ軍、シリア国境で攻勢 「ＩＳＩＳを完全排除」と発表
# Name: title, dtype: object
#
# [event 657]
# 16272    アフガンの米系大学に襲撃、１２人死亡 襲撃犯２人を殺害
# 16249      ダッカ襲撃 首謀者とみられる人物、銃撃戦の末に射殺
# Name: title, dtype: object
#
# [event 658]
# 16276    イタリア中部地震、死者２４７人に 死者増加の恐れも
# 16257    イタリア中部地震、死者２８１人に ２千人が避難生活
# Name: title, dtype: object
#
# [event 676]
# 16253         ジカ熱感染４１人に、渡航歴なし シンガポール
# 16247    シンガポールのジカ熱感染、５６人に 周辺国でも国内感染
# Name: title, dtype: object
#
# [event 687]
# 16238     トランプ氏、メキシコ大統領との会談を発表 移民政策発表前に
# 16230     トランプ氏、メキシコ大統領と会談 「壁の費用、話し合わず」
# 15444            メキシコ大統領、トランプ氏との会談を取りやめ
# 37187       イスラエル首相が2月15日に訪米、トランプ大統領と会談
# 36899              トランプ大統領、安倍首相とゴルフで親睦へ
# 36858    日米首脳会談は10日、フロリダでも首脳間の信頼構築＝官房長官
# Name: title, dtype: object
#
# [event 723]
# 16187    大聖堂前の車にガスボンベ、テロ計画容疑で女３人逮捕 パリ
# 16176       テロ容疑で逮捕の女３人、ＩＳＩＳから指示 パリ検察
# Name: title, dtype: object
#
# [event 726]
# 16194           北朝鮮、５回目の核実験 韓国大統領が言明
# 16173    国連安保理、北朝鮮を強く非難 オバマ氏は追加制裁に言及
# Name: title, dtype: object
#
# [event 732]
# 16109    ロシア、シリア沖へ空母派遣 国連では米ロ外相が応酬
# 15640    ロシアとトルコ、イランが外相会談 テロとの戦い強調
# Name: title, dtype: object
#
# [event 744]
# 16167         北朝鮮の核実験、「第２、第３の実施も」 韓国国防省
# 11250       イラン、ミサイル発射実験の実施認める 核合意違反は否定
# 11201    イラン、軍事演習にミサイル配備 追加制裁科した米への抗議表明
# Name: title, dtype: object
#
# [event 746]
# 16097    シリア停戦崩壊、アレッポへの空爆激化 ２００回の報告も
# 16093    アレッポ空爆激化、国連事務総長が国際社会に対応呼びかけ
# 15683      シリア軍がアレッポ東部を制圧、停戦へ ロシアが発表
# Name: title, dtype: object
#
# [event 748]
# 16162    イラン、領空付近の米軍哨戒機に「撃墜」警告 ペルシャ湾
# 15837       ロシア戦闘機、空母への着艦に失敗し墜落 シリア沖
# Name: title, dtype: object
#
# [event 755]
# 16143      米軍、モスル南郊の空軍基地に到着 奪還作戦近づく
# 38471    イラク軍、モスル東部で数日中に作戦再開へ＝米軍司令官
# 11596     イラク軍がモスル大学解放 モスル東部奪回へ向け進展
# Name: title, dtype: object
#
# [event 769]
# 16138    シリア空爆で２３人死亡、米ロが互いの停戦違反を非難
# 16089     シリア・アレッポにまた空爆 １２人死亡、９人負傷
# Name: title, dtype: object
#
# [event 785]
# 16134      米ロ、場外でも非難の応酬 シリア軍への空爆めぐり
# 16109     ロシア、シリア沖へ空母派遣 国連では米ロ外相が応酬
# 16100    安保理、アレッポ空爆巡り緊急会合 米ロの非難合戦続く
# Name: title, dtype: object
#
# [event 790]
# 16118        メルケル独首相、難民政策の不備に言及 議会選の敗北受け
# 37287    独ＳＰＤ首相候補、社会の分裂克服目指すと公約 メルケル氏に対抗
# 37080              仏フィヨン元首相、不正疑惑は「与党の策略」
# Name: title, dtype: object
#
# [event 799]
# 16112           サウジ主導のイエメン空爆、市民３０人死亡
# 16073    オランダ人ジャーナリスト、リビアでＩＳＩＳに撃たれ死亡
# Name: title, dtype: object
#
# [event 823]
# 16080          カシミールで衝突、パキスタン兵２人死亡
# 16069    武装集団がインド軍拠点襲撃、再び銃撃戦 カシミール
# 37260    イエメンで米兵4人死傷、トランプ政権初の軍事作戦で
# Name: title, dtype: object
#
# [event 828]
# 16074     ロシアが米に警告、シリア政権への攻撃は「中東に悪影響」
# 15521    米大使館のエルサレム移転、５月にも発表か 国際社会は警告
# Name: title, dtype: object
#
# [event 832]
# 16067      コロンビア和平合意、国民投票で否決 和平条件再交渉か
# 15839    コロンビア政府と極左ゲリラ、新和平案に調印 賠償で新規定
# 15805        コロンビア政府とＦＡＲＣ、新たな和平合意に署名へ
# 12489       コロンビア政府とFARCの新和平協定、24日に署名
# 12462     コロンビア、新和平協定に署名 反対押し切り議会で承認へ
# 15785         コロンビア政府とＦＡＲＣ、新たな和平合意に署名
# Name: title, dtype: object
#
# [event 864]
# 16045    イエメンで葬儀場空爆、１５５人死亡 サウジ主導連合軍か
# 15994           サウジ主導軍、イエメン葬儀場の誤爆認める
# Name: title, dtype: object
#
# [event 865]
# 16028    アレッポ空爆停止求める安保理決議否決、ロシアが拒否権発動
# 15719       国連安保理、アレッポ停戦案を否決 中ロが拒否権行使
# Name: title, dtype: object
#
# [event 876]
# 16023          シーア派寺院で銃撃、１４人死亡 アフガニスタン
# 15966           警察学校に襲撃、死傷者１６２人に パキスタン
# 15952    警察学校襲撃の死者６１人に、ＩＳＩＳが犯行声明 パキスタン
# 15858     アフガンの独領事館で自爆テロ、４人死亡 タリバーンが声明
# 15866     パキスタン宗教施設でテロ、死者５２人 ＩＳＩＳが犯行声明
# 15654              イエメン南部で自爆攻撃、兵士４１人死亡
# 12047             イエメンでISが自爆攻撃、兵士48人死亡
# Name: title, dtype: object
#
# [event 885]
# 16003             英スコットランド、独立問う２度目の住民投票を検討
# 37802    ブレグジットでスコットランドの要求却下なら独立問うべき＝行政府首相
# Name: title, dtype: object
#
# [event 886]
# 16002         フィリピン大統領、米との軍事同盟維持を表明
# 15983    フィリピン大統領、米国との決別を宣言 対中関係重視へ
# Name: title, dtype: object
#
# [event 893]
# 15942    ＩＳＩＳ、数百人規模の「自殺部隊」をモスルに配備か
# 15917     ＩＳＩＳ、モスル周辺の市民数万人を「人間の盾」に
# Name: title, dtype: object
#
# [event 896]
# 15989    マルコス元大統領の英雄墓地埋葬、フィリピン最高裁が判断へ
# 15988      比最高裁が判断を延期 マルコス元大統領の英雄墓地埋葬
# 15874       マルコス元大統領の「英雄墓地」埋葬、最高裁が認める
# Name: title, dtype: object
#
# [event 902]
# 15974    サウジアラビア、王子の死刑を執行 殺人事件で有罪
# 12169     「同性愛行為」で起訴の少女2人無罪に モロッコ
# Name: title, dtype: object
#
# [event 905]
# 15979       英政府、かつて同性愛で有罪になった数千人に恩赦
# 11281    英、同性愛者数万人に死後恩赦 「チューリング法」施行
# Name: title, dtype: object
#
# [event 910]
# 15978    ドゥテルテ氏、「米国との関係断絶ではない」 発言を釈明
# 15935    フィリピン大統領、問題発言の封印宣言 「神のお告げ」で
# Name: title, dtype: object
#
# [event 916]
# 15963    米海兵隊、ノルウェーに駐留の承認要請 米ロ関係緊張続く
# 15890     ノルウェー、米海兵隊の駐留承認 交替制で来年１月から
# Name: title, dtype: object
#
# [event 925]
# 15943    中国北西部の集合住宅で爆発 １０人死亡、１４７人負傷
# 15918     中国・重慶の炭鉱でガス爆発 １５人死亡、１８人不明
# Name: title, dtype: object
#
# [event 932]
# 15901    イラク軍、２年ぶりにモスル入り ＩＳＩＳと激しい市街戦
# 15895    モスル進攻、住民がキャンプへ避難 家族と２年ぶり再会も
# Name: title, dtype: object
#
# [event 933]
# 15891    タリバーン掃討作戦で市民３０人死亡、米軍認める アフガン
# 11639        米軍、「自己防衛」でアフガン市民33人死亡と発表
# Name: title, dtype: object
#
# [event 935]
# 15871     モスル奪還作戦、南郊の町に住民１００人の遺体
# 15868      ＩＳＩＳ、モスル西方で住民３００人近く拉致
# 15760    イラク軍兵士らの死者数、１１月は２０００人近く
# Name: title, dtype: object
#
# [event 943]
# 15929        米誌表紙飾ったアフガン女性、パキスタンで逮捕
# 15903    「アフガンの少女」の女性、保釈請求却下に パキスタン
# Name: title, dtype: object
#
# [event 957]
# 15920    韓国大統領、友人に国家文書漏洩 辞任要求強まる
# 15921    韓国検察、大統領の友人を緊急逮捕 文書流出疑惑
# Name: title, dtype: object
#
# [event 961]
# 15912     中国の国産ステルス機「Ｊ２０」、航空ショーで初公開へ
# 15923    中国国産ステルス機「Ｊ２０」、初の一般公開 大空を飛翔
# Name: title, dtype: object
#
# [event 970]
# 15897    「別の国から買う」 比警察トップ、米国の銃売却中止報道に反発
# 15905       米から買えなければロシアから、銃売却中止報道で比大統領
# Name: title, dtype: object
#
# [event 984]
# 12545    サルコジ氏、仏大統領選レースから脱落 右派陣営2元首相が決選投票に
# 15813         仏大統領選予備選、中道右派が決選投票へ サルコジ氏は敗退
# 12424       仏右派陣営の決選投票、フィヨン氏が圧勝 次期大統領「本命」に
# 15781          「フランスのサッチャー」フィヨン氏が勝利 仏右派予備選
# Name: title, dtype: object
#
# [event 987]
# 15870    中国政府、香港独立派２議員の就任阻む 前日には抗議デモ
# 15827      高等法院の「資格取り消し」判断、２議員が異議 香港
# Name: title, dtype: object
#
# [event 998]
# 15865    少年が４０ｍの枯れ井戸に落下、救出作業４日間続く 中国
# 15857       枯れ井戸に落下した少年、遺体で見つかる 中国北部
# Name: title, dtype: object
#
# [event 1000]
# 15853        比大統領、トランプ氏当選を好感 「どちらも悪態好き」
# 12494    クリントン氏を「傷つけたくない」 トランプ氏、訴追の構え撤回
# Name: title, dtype: object
#
# [event 1001]
# 15852    トランプ氏、習主席との電話会談「なし」 中国「あった」
# 15840       トランプ氏と習主席が電話会談、米中間の協力を確認
# Name: title, dtype: object
#
# [event 1002]
# 12503    トランプ氏の過激ツイート「なぜ気にする？」 側近が批判を一蹴
# Name: title, dtype: object
#
# [event 1003]
# 15804            安倍首相、米国抜きのＴＰＰは「意味がない」
# 37366    焦点：米国抜きのＴＰＰ考えず、今後の通商交渉へ新組織も検討
# Name: title, dtype: object
#
# [event 1008]
# 15848          数十万人参加の大規模デモ、大統領の退陣求める ソウル
# 15808            首相退陣求めるデモ、数千人が参加 マレーシア首都
# 15779           朴大統領の退陣要求する大規模デモ、５週連続に 韓国
# 12422    韓国ソウルの抗議デモ、最大規模に ろうそくともして朴氏退陣求める
# 11936     クリスマスもサンタ姿でデモ参加 朴氏即時退陣求め55万人 韓国
# 15604        韓国のデモ９週目に、朴大統領の退陣求め 「サンタ」も参加
# Name: title, dtype: object
#
# [event 1013]
# 15842    韓国検察、朴大統領に聴取要請 疑惑への批判止まず
# 15817    韓国検察、朴大統領を取り調べへ 友人など３人起訴
# 37812     韓国特別検察、2月初旬までに朴槿恵大統領を聴取
# 36751        韓国の朴大統領が聴取拒否、事前報道に反発
# Name: title, dtype: object
#
# [event 1017]
# 15849     トランプ氏とプーチン大統領が電話会談 米ロ関係の将来語る
# 11343       米ロ大統領が電話会談、関係改善への「有意義な出発点」
# 37314     米ロ大統領が電話会談、関係改善やシリア巡る連携強化で合意
# 36924    トランプ米大統領、ウクライナ・ロシア問題で両国との協力表明
# Name: title, dtype: object
#
# [event 1018]
# 15832     安倍首相、トランプ氏と会談へ 日米同盟の重要性確認
# 15829    安倍首相とトランプ氏が会談、日米の「信頼関係」に確信
# 37307      日米首脳が電話会談、安倍首相「同盟の重要性共有」
# 37085      日米首脳会談、2日目はフロリダ開催で調整＝政府筋
# 36644                日米首脳会談：識者はこうみる
# Name: title, dtype: object
#
# [event 1023]
# 12431     シリア軍、アレッポ東部に猛攻 ラッカ周辺では米軍に初の戦死者
# 15769           シリア政府軍、アレッポ東部に進入 地上攻撃を開始
# 12412             シリア政府軍猛攻のアレッポ、市民1万人が脱出
# 12377    シリア軍、アレッポ北東部を奪還 反体制派にとって「最大の敗北」
# 12359    シリア・アレッポ東部から3日間で市民2万人が退避 赤十字国際委
# Name: title, dtype: object
#
# [event 1036]
# 12361        有志連合によるシリア軍空爆、米軍誤りあったこと認める
# 15754      米軍、シリア空爆でのミス認める ロシアからの電話も通じず
# 11223         民間人犠牲のイエメン軍事作戦は「成功」、米政府主張
# 36971    米国防長官、中国の南シナ海での活動を批判 劇的な軍展開は不要
# Name: title, dtype: object
#
# [event 1039]
# 12437    緑の党、米大統領選の「再集計」要求 トランプ氏勝利の激戦州で
# 12398       ミシガンはトランプ氏が勝利 米大統領選、全州で結果確定
# 12299     緑の党、ペンシルベニア州での再集計請求取り下げ 米大統領選
# Name: title, dtype: object
#
# [event 1041]
# 15821         アレッポ東部、空爆で６１人死亡 フル稼働の病院ゼロに
# 15816      アレッポ空爆、「ホロコースト」と活動家 毒ガス使用の疑いも
# 12431     シリア軍、アレッポ東部に猛攻 ラッカ周辺では米軍に初の戦死者
# 15769           シリア政府軍、アレッポ東部に進入 地上攻撃を開始
# 12377    シリア軍、アレッポ北東部を奪還 反体制派にとって「最大の敗北」
# Name: title, dtype: object
#
# [event 1043]
# 12546     習主席がオバマ大統領と最後の首脳会談、米中関係は「転換点」
# 12521    オバマ大統領、日米同盟への「揺るぎない責任」を安倍首相に保証
# Name: title, dtype: object
#
# [event 1045]
# 15820            ドバイ当局、強姦被害訴えた英女性を逮捕
# 15801    英女性が訴えた強姦被害、ドバイ当局は「合意の上」と断定
# Name: title, dtype: object
#
# [event 1047]
# 12544         インド北部で急行列車が脱線、少なくとも91人死亡
# 12553       インド列車脱線事故、死者120人に 生存者の捜索続く
# 12524     インド列車脱線事故、死者142人に 2000人超が乗車か
# 11872    インド北部で急行列車が脱線、30人死傷 先月の事故現場近く
# Name: title, dtype: object
#
# [event 1052]
# 12543    生存者「芯まで震えた」、死者100人超える 印列車脱線事故
# 12553       インド列車脱線事故、死者120人に 生存者の捜索続く
# 12524     インド列車脱線事故、死者142人に 2000人超が乗車か
# Name: title, dtype: object
#
# [event 1054]
# 12424    仏右派陣営の決選投票、フィヨン氏が圧勝 次期大統領「本命」に
# 36905     仏大統領選決選投票、マクロン氏がルペン氏に勝利の公算＝調査
# Name: title, dtype: object
#
# [event 1056]
# 12325         オランド仏大統領、再選を断念 テレビ演説で表明
# 15750    オランド仏大統領、再選への出馬断念 テロなどで支持率低迷
# 12250                バルス仏首相、大統領選出馬を表明
# 15725    バルス氏が大統領選出馬へ首相辞任、後任はカズヌーブ氏 仏
# Name: title, dtype: object
#
# [event 1060]
# 12536      英バッキンガム宮殿の大規模改修、政府が約500億円支出
# 12490    英バッキンガム宮殿の改修費用500億円、女王に負担求める声
# Name: title, dtype: object
#
# [event 1061]
# 12535    米次期国防長官に「狂犬」マティス氏有力、元中央軍司令官
# 12328      トランプ氏、次期国防長官に「狂犬」マティス氏を指名
# Name: title, dtype: object
#
# [event 1070]
# 12527        リビア部族間衝突で20人以上死亡、発端はサル？
# 15819    部族衝突の激化で７０人死傷、ペットのサルが発端 リビア
# Name: title, dtype: object
#
# [event 1072]
# 12532    ローマ法王、中絶への司祭による「許し」 無期限で継続
# 15800    神父が「中絶の罪」許す権限、無期限で延長 ローマ法王
# Name: title, dtype: object
#
# [event 1074]
# 12531             仏当局が「テロ計画阻止」 2都市で7人逮捕
# 12452       逮捕された容疑者ら、12月1日のパリ襲撃を計画 警察筋
# 12443    パリ襲撃計画、ISが指示か シャンゼリゼやディズニー標的に？
# Name: title, dtype: object
#
# [event 1075]
# 12287             米国人女性、インド首都での集団レイプ被害訴える
# 15730         米国人女性が強姦被害か、高級ホテルの部屋で インド首都
# 12054       女性に車で送ると声をかけ性的暴行、運転手の男を逮捕 インド
# 11899              米女性集団レイプ、容疑者4人逮捕 インド首都
# 11785    妻と孫殺害で服役中の77歳男、別の受刑者をトースターで殺害か 豪
# Name: title, dtype: object
#
# [event 1077]
# 15812          福島県沖でＭ７．４の地震 津波警報発令
# 15810    福島県沖Ｍ７．４の地震、仙台港で１．４ｍの津波観測
# Name: title, dtype: object
#
# [event 1082]
# 12323     南スーダンで「民族浄化」進行、国連の人権視察団が警告
# 12022    国連、アレッポに住民退避の監視団派遣 安保理が決議採択
# Name: title, dtype: object
#
# [event 1090]
# 12515        リビア統一政府勢力、港町シルトでIS残党に迫る
# 12251       リビアのISに打撃 最後の主要拠点、政府側が奪還
# 15718       リビア部隊、中部シルトのＩＳＩＳ支配地を全て奪還
# 11173    IS、アレッポ最後の拠点「完全包囲下」に 政権側が攻勢
# Name: title, dtype: object
#
# [event 1100]
# 12519    パリ近郊の高速道路で強盗事件、被害額は少なくとも6億円弱
# 15799     カタール人姉妹、６億円相当の強盗被害 パリ郊外の路上で
# Name: title, dtype: object
#
# [event 1104]
# 12497    地中海で8人死亡、イタリアに到着した移民は過去最高レベルに
# 11942    2016年に地中海で死亡した移民・難民が5000人に、国連
# Name: title, dtype: object
#
# [event 1119]
# 12480    裁判員が居眠り、裁判やり直しで性的暴行の男が無罪に デンマーク
# 12469    キリスト教徒夫婦をリンチし窯で殺害、5人に死刑判決 パキスタン
# Name: title, dtype: object
#
# [event 1124]
# 12478      モスル奪還戦、シリアと結ぶIS最後の補給路を遮断
# 15796    イラク軍、モスルを完全包囲 ＩＳＩＳの補給ルート断つ
# Name: title, dtype: object
#
# [event 1126]
# 12411    トランプ氏「数百万人が違法投票」 米大統領選、再集計に反発
# 37446    トランプ大統領、選挙での不正投票を依然確信＝ホワイトハウス
# 37411      トランプ氏、米大統領選での「不正投票」めぐり調査要請へ
# 11391         トランプ氏、不正投票の調査宣言 根拠は依然示さず
# Name: title, dtype: object
#
# [event 1128]
# 15792    「雷雨ぜんそく」で３人死亡、花粉と悪天候で発生 豪
# 12425     オーストラリアで発生の「雷雨ぜんそく」、6人死亡
# Name: title, dtype: object
#
# [event 1131]
# 12282    朴大統領のスキャンダルめぐる聴聞会開始、財閥トップも出席へ
# 12265          国政介入疑惑で財閥のトップ8人を聴聞、韓国国会
# Name: title, dtype: object
#
# [event 1134]
# 15803           発電所工事で足場が倒壊、４０人死亡 中国
# 12468         建設中の発電所で足場が倒壊、67人死亡 中国
# 12436    中国、発電所の足場倒壊の死者74人に 当局は13人拘束
# Name: title, dtype: object
#
# [event 1146]
# 12450        トルコのEU加盟交渉の凍結を、欧州議会が決議採択
# 12445    トルコ大統領「移民に国境を開放」、加盟交渉渋るEUに脅し
# Name: title, dtype: object
#
# [event 1150]
# 12235     ロヒンギャ2万1000人、ミャンマーからバングラデシュへ脱出
# 11848    ミャンマーからロヒンギャ5万人流入、バングラデシュ「深い懸念」
# Name: title, dtype: object
#
# [event 1152]
# 12448    トランプ氏側近、国務長官人事に異論 ロムニー氏起用めぐり対立
# 11725     駐カナダ米大使が辞任表明、トランプ次期政権の徹底見直しで初
# 38150      米選挙戦中のサイバー攻撃、トランプ氏がロシアの関与認める
# Name: title, dtype: object
#
# [event 1153]
# 12457    シリア・アレッポ、政府軍の爆撃で子ども5人含む市民32人死亡
# 11885          IS支配下の村で空爆、市民22人死亡 シリア東部
# Name: title, dtype: object
#
# [event 1154]
# 12253    ロシアの野戦病院に反体制派が砲撃、3人死傷 シリア・アレッポ
# 11091               ロシア軍誤爆でトルコ兵3人死亡 シリア
# Name: title, dtype: object
#
# [event 1163]
# 12446    次期米政権、安保担当副補佐官にベテランのマクファーランド氏
# 38431      トランプ氏、安全保障・対テロ担当補佐官にボサート氏指名
# Name: title, dtype: object
#
# [event 1169]
# 15788          キューバのカストロ前議長が死去、国営メディア
# 15789             キューバのカストロ前議長が死去、９０歳
# 12438        キューバのカストロ前国家評議会議長が死去、90歳
# 12427    フィデル・カストロ前国家評議会議長死去、各国指導者の反応
# Name: title, dtype: object
#
# [event 1174]
# 15778     イスラエルで山林火災が多発、「放火テロ」を警戒
# 15780    大規模山林火災、放火容疑で２３人拘束 イスラエル
# Name: title, dtype: object
#
# [event 1178]
# 12413    同性愛行為の罪で起訴された少女2人、「友人関係」主張 モロッコ
# 12169            「同性愛行為」で起訴の少女2人無罪に モロッコ
# Name: title, dtype: object
#
# [event 1182]
# 12310             米3州の票再集計、トランプ氏側が中止要求
# 12299    緑の党、ペンシルベニア州での再集計請求取り下げ 米大統領選
# Name: title, dtype: object
#
# [event 1191]
# 15705               シリア政府軍、アレッポ東部の大半を掌握
# 12200    シリア政府軍、アレッポ旧市街全域を制圧 反体制派は停戦求める
# 12195        シリア政府軍、アレッポ攻撃再開 国連、即時停戦を要求
# 11948        シリア政府軍、アレッポ奪還を宣言 反体制派の撤退完了
# Name: title, dtype: object
#
# [event 1194]
# 15763    カストロ氏追悼、遺灰がキューバ横断へ 革命の旅路再現
# 12403          【写真特集】カストロ前議長の死を悼む人々
# Name: title, dtype: object
#
# [event 1203]
# 12409    インドネシア軍ヘリ墜落、3日後にパイロット救出も乗員4人不明
# 12165       ヘリ墜落で不明の兵士、2週間ぶり生存確認 インドネシア
# Name: title, dtype: object
#
# [event 1208]
# 12407    米オハイオ州立大で襲撃事件、9人負傷 車と刃物で通行人狙う
# 12394    オハイオ州立大襲撃、ソマリア系学生の犯行か テロ視野に捜査
# 12350    米大学襲撃犯、「テロ組織と直接関係なし」 過激思想に賛同か
# Name: title, dtype: object
#
# [event 1209]
# 12406      トランプ氏、キューバ国交再断絶を示唆 「より良い取引」要求
# 12148    中国政府、深刻な懸念を表明 「一つの中国」疑問視のトランプ氏に
# Name: title, dtype: object
#
# [event 1212]
# 12166     CIA調査「トランプ氏勝利のため露が大統領選に干渉」、米紙報道
# 12172      米共和党、ロシアの米大統領選干渉報道を否定 民主党は調査要求
# 12156    トランプ氏、露サイバー攻撃めぐるCIAの結論は 「ばかげている」
# 12139         露による米大統領選への干渉、ホワイトハウスが調査を支持
# 12094        米民主党へのハッキング「プーチン氏が直接指示」 情報当局
# 12055     米FBIとCIA、大統領選への「ロシア介入」で結論一致 米報道
# Name: title, dtype: object
#
# [event 1219]
# 12379    13年アルジェリア人質事件のアルカイダ系首謀者、仏軍空爆で死亡か
# 12132         エジプト教会爆発は「自爆攻撃」 大統領が断定、4人拘束
# Name: title, dtype: object
#
# [event 1225]
# 15770    朴大統領、退陣めぐる決断を「国会にゆだねる」と表明 韓国
# 12382         韓国・朴大統領「国会に委ねる」、早期退陣を示唆
# Name: title, dtype: object
#
# [event 1227]
# 12384    ハイチ、やり直しの大統領選 第1回投票の暫定結果発表 モイーズ氏が当選
# 11769             ハイチ大統領選、モイーズ氏の当選確定 選管が正式発表
# Name: title, dtype: object
#
# [event 1230]
# 15774     コロンビアで旅客機墜落 ７６人死亡、サッカー選手ら搭乗
# 15762    コロンビア墜落事故、サッカー選手ら６人生存 死者７１人に
# Name: title, dtype: object
#
# [event 1240]
# 12374               米オハイオの襲撃事件、ISが犯行声明
# 12350    米大学襲撃犯、「テロ組織と直接関係なし」 過激思想に賛同か
# Name: title, dtype: object
#
# [event 1250]
# 12356      コロンビア議会、FARCとの新和平協定を承認
# 15751    コロンビア和平案、議会で承認 内戦が正式に終結へ
# Name: title, dtype: object
#
# [event 1254]
# 12367      IS、モスル脱出図った数十人を射殺 7歳の子どもも 国連
# 15759        ５０万人が水不足、ＩＳＩＳの妨害でさらに悪化 モスル
# 12204    有志連合、イラクとシリアで「IS戦闘員5万人殺害」 米軍幹部
# 15712              米軍殺害のＩＳＩＳ戦闘員、累計で５万人に
# 12025                モスル奪還作戦、10万人超が避難民に
# 11164           トルコのIS掃討一斉捜査、拘束者数750人超に
# Name: title, dtype: object
#
# [event 1258]
# 12110    有志連合、パリ同時攻撃関与のIS幹部ら殺害 ラッカで空爆
# 15674       ＩＳＩＳ幹部３人、米空爆で死亡 パリ同時テロ関与も
# Name: title, dtype: object
#
# [event 1263]
# 15747       コロンビア墜落事故 原因は燃料切れか、現場で火災発生せず
# 12349     コロンビア墜落、操縦士が直前に「燃料切れ」報告か テープ流出
# 15756       選手１人が右脚切断、直前に搭乗やめた４人も 墜落機の明暗
# 12181    コロンビア墜落、直前に予備燃料の問題報告 ボリビア当局が隠蔽か
# 12042               コロンビア墜落機の操縦士、飛行訓練不足か
# 15642          コロンビア墜落事故 原因は人為的ミス、ボリビア当局
# 38465        コロンビア墜落、燃料不足が原因 航空当局「人為的ミス」
# Name: title, dtype: object
#
# [event 1273]
# 15757       カストロ前議長の葬列が出発、キューバ革命誕生の地へ
# 12297       キューバ、カストロ前議長の遺灰埋葬 革命発祥の地に
# 15743    キューバのカストロ氏、革命の地に埋葬 葬儀に各国首脳参加
# Name: title, dtype: object
#
# [event 1293]
# 12146    「一つの中国」疑問視のトランプ氏は「子ども」 米敵対勢力支援を警告、中国紙
# 12148          中国政府、深刻な懸念を表明 「一つの中国」疑問視のトランプ氏に
# 15692                中国、トランプ氏の発言に「重大な懸念」 台湾問題で
# Name: title, dtype: object
#
# [event 1294]
# 12329    コロンビア墜落事故、チャーター機運航会社の免許停止
# 15726     コロンビア墜落、チャーター機運航会社トップを拘束
# Name: title, dtype: object
#
# [event 1304]
# 12317    北朝鮮、ソウル標的に砲撃演習 「たたきつぶす」と金正恩氏
# 12170         北朝鮮が軍事演習、韓国大統領府などを標的と想定
# Name: title, dtype: object
#
# [event 1309]
# 12307    トランプ次期米大統領、台湾総統と電話会談 中国が反発する恐れ
# 12320          トランプ氏、台湾総統との電話会談についてツイート
# 12311      トランプ氏と蔡総統の電話会談は「台湾側の策略」、中国外相
# 12291         トランプ氏と蔡総統の電話会談、中国が米国に厳重抗議
# Name: title, dtype: object
#
# [event 1312]
# 12122             反体制派、アレッポ撤退へ シリア政府軍と合意
# 15683          シリア軍がアレッポ東部を制圧、停戦へ ロシアが発表
# 12099    シリア・アレッポ、市民避難で新合意か 反体制派発表も政府は否定
# 12076             シリア・アレッポ、反体制派の撤退で新たに合意
# 12086     シリア反体制派、アレッポ撤退を開始 アサド大統領「解放」祝う
# 15671           アレッポ東部、市民の避難開始 逃れる先も戦闘地域
# 15667         アレッポからの避難が停止、国連事務総長「地獄と同じ」
# Name: title, dtype: object
#
# [event 1314]
# 15709         韓国国会、朴大統領の弾劾案可決
# 12180    韓国国会、朴槿恵大統領の弾劾訴追案を可決
# Name: title, dtype: object
#
# [event 1323]
# 38783          中国、空母編隊が初の実弾演習 渤海で実施
# 12073    中国空母艦隊が初の実弾演習、米国・台湾に軍事力を誇示
# 15672       中国空母の艦隊、渤海で初の実弾演習 軍事力誇示
# Name: title, dtype: object
#
# [event 1326]
# 15738         トランプ氏、比大統領の麻薬対策を「評価」 電話会談
# 38755    トランプ氏、「一つの中国」政策で今すぐの見直し提案せず＝側近
# 38468        オバマ大統領「出馬できれば勝てた」、トランプ氏は反論
# Name: title, dtype: object
#
# [event 1333]
# 12302     米カリフォルニア州でパーティー中に火災、死者40人の恐れ
# 12276            米カリフォルニア州の倉庫火災、死者33人に
# 12258    米カリフォルニア州の倉庫火災、死者36人に 刑事捜査を開始
# Name: title, dtype: object
#
# [event 1343]
# 15741      アレッポの少女、ツイッターからアカウント消える
# 12248    戦禍のシリア・アレッポからつぶやき、少女の無事確認
# Name: title, dtype: object
#
# [event 1344]
# 12277    イタリア国民投票、大差で否決 レンツィ首相が引責辞任
# 15745    伊国民投票、憲法改正案を否決 レンツィ首相が辞任表明
# Name: title, dtype: object
#
# [event 1345]
# 15720          伊大統領、レンツィ首相の留任を要請 予算案承認まで
# 36929    英首相のＥＵ離脱戦略、身内の保守党議員から批判も 議会審議控え
# 36886       米最高裁判事に指名のゴーサッチ氏、民主党が独立性を疑問視
# 36771     米最高裁判事指名のゴーサッチ氏、大統領令めぐりトランプ氏批判
# 11116     米最高裁判事候補ゴーサッチ氏、トランプ氏の司法批判に「失望」
# Name: title, dtype: object
#
# [event 1349]
# 15675           アレッポ東部への砲撃再開か 住民の避難は始まらず
# 12091          アレッポで激しい戦闘、撤退合意は履行されず シリア
# 12099    シリア・アレッポ、市民避難で新合意か 反体制派発表も政府は否定
# 15671           アレッポ東部、市民の避難開始 逃れる先も戦闘地域
# 12070           アレッポ東部、約5万人がまだ退避できず 国連特使
# 15667         アレッポからの避難が停止、国連事務総長「地獄と同じ」
# 12040             アレッポ撤退、再び中断 避難用バス襲撃で死者
# 15656          アレッポからの避難再開、移送用バスに放火で一時中断
# Name: title, dtype: object
#
# [event 1360]
# 12268      安倍首相、年内に真珠湾訪問へ 歴代首相で初
# 15729    安倍首相、今月下旬に真珠湾訪問へ 現職首相で初
# Name: title, dtype: object
#
# [event 1376]
# 12240            上海でiPhoneの発火報告相次ぐ、アップルに対処要請
# 12223    中国でのiPhone発火、アップルは「外部からのダメージ」が原因と主張
# Name: title, dtype: object
#
# [event 1384]
# 12178    「不法移民の子には無償教育中止」 仏極右ルペン氏が主張
# 15706     仏右翼政党ルペン党首、不法移民の子への無償教育に異議
# Name: title, dtype: object
#
# [event 1392]
# 15723    インドネシア・アチェ州でＭ６．５の地震、２５人死亡
# 15727     インドネシア地震、死者５２人に 生存者の捜索続く
# Name: title, dtype: object
#
# [event 1393]
# 12217        インドネシアの地震、死者25人に 数百人が負傷か
# 12226            【写真特集】インドネシア・スマトラ島地震
# 12026    エクアドル沖でM5.7の地震、3人死亡 建物も甚大な被害
# Name: title, dtype: object
#
# [event 1397]
# 12098    ドゥテルテ比大統領、市長時代に自ら殺害実行 スピーチで発言
# 15685       「自分の手で容疑者を殺した」 フィリピン大統領が公言
# 12058        ドゥテルテ比大統領、市長時代の容疑者殺害に開き直り
# Name: title, dtype: object
#
# [event 1398]
# 12103    住民がギャング団リーダーの母親拘束 拉致被害者の解放要求で メキシコ
# 12097           犯罪グループの身内拘束で拉致男性の解放に成功 メキシコ
# Name: title, dtype: object
#
# [event 1399]
# 12000     トルコの露大使射殺、容疑者の警官は自分の身分証で入場
# 12004    ベルリンのトラック突入、拘束されたのは亡命希望者の男性
# Name: title, dtype: object
#
# [event 1405]
# 12231        インドネシア地震 死者数が増加の一途、97人に
# 12226           【写真特集】インドネシア・スマトラ島地震
# 12203      インドネシア・スマトラ島地震、死者数100人超える
# 12173    インドネシア・アチェの地震、避難住民4万5000人以上
# Name: title, dtype: object
#
# [event 1406]
# 12228    イスラエルがミサイル発射、シリア首都郊外に着弾 地元メディア
# 11615    イスラエル軍機がシリア空軍基地にミサイル攻撃か、シリア軍発表
# Name: title, dtype: object
#
# [event 1407]
# 12224       パキスタンで国内線旅客機が墜落、乗客乗員47人搭乗
# 11906    旅客機が滑走路外れる、乗客15人負傷 インド・ゴアの空港
# Name: title, dtype: object
#
# [event 1408]
# 12225    パキスタン航空機墜落、48人全員死亡 元国民的歌手も犠牲に
# 15721     パキスタン機墜落、４７人全員死亡 元ポップスターも犠牲に
# Name: title, dtype: object
#
# [event 1429]
# 12197               トランプ氏に備え中国は核兵器増産を、国営紙が論説掲載
# 12146    「一つの中国」疑問視のトランプ氏は「子ども」 米敵対勢力支援を警告、中国紙
# 12148          中国政府、深刻な懸念を表明 「一つの中国」疑問視のトランプ氏に
# 11415                中国紙「トランプ米新大統領に対抗し、核強化すべき」
# Name: title, dtype: object
#
# [event 1431]
# 12206       世界一の人工クリスマスツリー、大司教の一声で計画中止 スリランカ
# 12127    世界一の人工クリスマスツリー建設再開、批判的な大司教を説得 スリランカ
# Name: title, dtype: object
#
# [event 1454]
# 15691          キリスト教教会で爆発、２５人死亡 エジプト首都
# 12142    エジプト・カイロのコプト教会で爆発 23人死亡、49人負傷
# Name: title, dtype: object
#
# [event 1455]
# 12132      エジプト教会爆発は「自爆攻撃」 大統領が断定、4人拘束
# 11792    トルコ銃乱射犯、シリアでIS参加か 実戦経験を犯行に利用？
# 11782            トルコ銃乱射、実行犯の身元特定 外相認める
# 15540           トルコ銃乱射、実行犯の身元を特定 依然逃走中
# Name: title, dtype: object
#
# [event 1458]
# 12194          オバマ氏、大統領選サイバー攻撃の「徹底調査」を指示
# 12172     米共和党、ロシアの米大統領選干渉報道を否定 民主党は調査要求
# 38940    米大統領選にロシア干渉とのＣＩＡ分析、統括当局は不支持＝関係筋
# 38819       大統領選でのサイバー攻撃、トランプ氏が米政府の対応に疑問
# 38808    プーチン氏がサイバー攻撃指示、トランプ氏勝利狙う＝米政府関係者
# 11757             米情報機関トップ、ロシア選挙介入の結論に自信
# Name: title, dtype: object
#
# [event 1459]
# 12139     露による米大統領選への干渉、ホワイトハウスが調査を支持
# 11625    米国防長官候補のマティス氏、上院公聴会でロシアを痛烈批判
# 15499      米次期国務長官、南シナ海問題で対中批判 強硬姿勢鮮明
# 11598      ロシアの米大統領選妨害疑惑、米上院委員会が調査を開始
# Name: title, dtype: object
#
# [event 1460]
# 12075              大統領選妨害にプーチン氏関与、米政府が見解
# 38763         プーチン氏のサイバー攻撃関与、オバマ米大統領強く示唆
# 12069    露大統領に「やめろと言った」 オバマ氏、サイバー攻撃の報復宣言
# 12059       クリントン氏、大統領選敗北でプーチン氏とFBI長官を非難
# 11837         ロシア大統領、米国への報復を留保 トランプ政権に期待
# Name: title, dtype: object
#
# [event 1474]
# 12177       ナイジェリアの教会で屋根が崩落、死者200人の恐れも
# 12138    ナイジェリアの教会屋根崩落、60人の死亡確認 200人負傷
# Name: title, dtype: object
#
# [event 1475]
# 15702    シリアの古代都市パルミラ、ＩＳＩＳが再侵攻 政府軍撤退
# 12149    シリア古代都市パルミラ、ISが再び制圧 遺跡破壊の危機
# Name: title, dtype: object
#
# [event 1476]
# 15697             ガス輸送列車が脱線して爆発、５人死亡 ブルガリア
# 12160    ガス輸送列車が脱線し爆発、7人死亡 周囲にも大きな被害 ブルガリア
# Name: title, dtype: object
#
# [event 1480]
# 12154     イエメンで軍を狙った自爆攻撃、48人死亡 ISが犯行声明
# 11818    イラク首都で自爆攻撃、少なくとも32人死亡 ISが犯行声明
# Name: title, dtype: object
#
# [event 1481]
# 12145         トルコ連続爆弾攻撃、クルド系武装組織が犯行声明
# 15696    イスタンブール爆発、クルド系組織が犯行声明 死者３８人に
# 12141    トルコ連続爆弾攻撃、クルド系政党関係者ら200人以上拘束
# Name: title, dtype: object
#
# [event 1485]
# 15695      教会が突如倒壊、礼拝中の信者ら５０人死亡 ナイジェリア
# 11930    クリスマスイブ礼拝中の教会前で爆発、13人負傷 フィリピン
# Name: title, dtype: object
#
# [event 1491]
# 12143    ニュージーランド新首相にイングリッシュ氏
# 15694    ニュージーランド新首相にイングリッシュ氏
# Name: title, dtype: object
#
# [event 1499]
# 38703    トランプ氏、次期米大統領に正式選出 選挙人投票で過半数確保
# 12028          米大統領選で選挙人投票、トランプ氏が正式に勝利
# Name: title, dtype: object
#
# [event 1500]
# 38939    米国務長官候補のエクソンＣＥＯ、ロシアとの関係に懸念＝上院議員
# 38906      米民主党、ティラーソン氏の国務長官指名承認公聴会に向け調査
# Name: title, dtype: object
#
# [event 1508]
# 38941              ドル115円前半、ポジション調整終了後に買い優勢
# 38915                 ドルは115円前半、日銀短観はほぼ無風通過
# 38894             ドル115円前半で方向感出ず、ＦＯＭＣを前に様子見
# 38864          ドルは117円前半、ＦＯＭＣ後の高値から利食いに押される
# 38847                 ドル117円半ば、米利上げ受けた上昇は一服
# 38837       ドル一時118円半ば、米利上げ観測と新政権への期待で＝ＮＹ市場
# 38805           ドルは118円前半でもみ合い、株価のプラス圏推移を眺め
# 38800               ドル118円前半、上昇一服だが地合いは依然強い
# 38736         正午のドルは117円半ばにじり安、株安で利益確定売りが先行
# 38724              ドル117円前半、クリスマス休暇控えた調整売りも
# 38687    正午のドルは117円前半で底堅い、日銀の政策現状維持決定後に持ち直し
# 38682          ドル117円半ば、株高・米金利上昇にらみ日銀総裁会見待ち
# 38635              正午のドルは117円後半、海外勢の参加乏しく軟調
# 38625               ドル117円半ばでもみ合い、商い薄く方向感欠く
# 38582           正午のドルは117円半ば、連休前に様子見ムードが支配的
# 38569               ドル117円半ばで小動き、休暇意識し方向感出ず
# 38511              正午のドルは117円付近、調整売り圧力に押される
# 38501              ドル117円前半で方向感出ず、休暇モードで薄商い
# 38464               ドルは117円前半、国内景気指標は弱さが目立つ
# 38456              ドル117円前半で方向感出ず、参加者限られ薄商い
# 38416                 ドルは117円半ば、実需の買いが押し上げる
# 38415             ドル117円半ばで一進一退、実需筋の年末フロー観測
# 38384               ドルは116円後半、株安や調整の売りで上値重い
# 38376             ドル116円後半、短期筋のロスカット売りに押される
# 38372                   ドルは116円半ば、材料難で方向感欠く
# 38363                ドル116円半ば、2016年は年間で3％下落
# 38299           正午のドルは117円後半、株の大幅高でリスク選好モード
# 38287                    ドル118円前半、株高をながめ底堅い
# 38247          正午のドルは116円半ば、短期筋の売りと実需の買いが交錯
# 38239                ドル116円半ば、ロングの巻き戻し受け全面安
#                         ...
# 37867       ドル114円付近で上値重い、英首相演説や米大統領就任式など意識
# 37831     ドルは114円付近、英首相演説控え英ポンドは1.20ドル台で安定的
# 37819               ドル113円前半で上値重い、英首相の演説を警戒
# 37775        ドルは113円付近でもみ合い、トランプ氏のドル高けん制を警戒
# 37757              ドル113円前半に持ち直し、国内勢の買いが支えに
# 37510         ドルは112円後半、ムニューチン氏発言で一時8週間ぶり安値
# 37506                 ドル112円後半、下値は押し目買いが支える
# 37459                    ドルは113円半ば、米長期金利は反落
# 37437               ドル113円半ばにじり高、米長期金利が持ち直し
# 37400             ドルは113円前半で一進一退、下値は押し目買い観測
# 37389              ドル113円前半、ドル指数は7週間ぶり安値に下落
# 37343         ドルは高値もみ合い、115円付近でオプション絡みの防戦売り
# 37267                 ドルは114円前半に下落、リスク回避ムード
# 37257                 ドル114円半ば、「トランプ旋風」に疲労感
# 37211          ドルは113円半ばで上値重い、日銀は政策の現状維持を決定
# 37204         ドル113円半ばで上値重い、引き続き「トランプリスク」警戒
# 37145              ドル113円前半、113円ばさみのもみ合いに終始
# 37137             ドル113円前半で方向感出ず、米大統領の動向を警戒
# 37086                 ドルは113円付近、下値は国内勢の買い需要
# 37071                   ドル112円半ばで上値重い、株安を眺め
# 37026         ドルは112円後半、円債利回り上昇を手掛かりとする円買いも
# 37001                ドル113円付近、日銀の指し値オペ通告で急騰
# 36933               ドルは112円前半、日米首脳会談控え上値が重い
# 36938                  ドル／円方向感欠く、日米首脳会談に警戒感
# 36888            ドルは111円後半、ユーロ／円と共に2カ月ぶり安値圏
# 36868             ドル111円後半でもみ合い、株価の下げ幅縮小を眺め
# 36815              ドルは112円前半で上値重い、材料欠き方向感出ず
# 36809                ドル112円前半で底堅い、上値追いには力不足
# 36581         株安でドル113円前半に下落、米ＦＲＢ議長の議会証言に関心
# 36426           ドル／円は国内勢の買いでじり高、米連休控え上昇限定的に
# Name: title, Length: 70, dtype: object
#
# [event 1509]
# 38942             日経平均は6日続伸、押し目買いで後場プラス圏に
# 38897           日経平均は7日続伸、利益確定売りと押し目買いが交錯
# 38862     日経平均は8日続伸、ＦＯＭＣ後の円安が支援 下げ転換後切り返す
# 38809     日経平均は9日続伸、欧米株高・円安を好感 連日の年初来高値更新
# 38732             日経平均は10日ぶり小反落、短期過熱感など重し
# 38626        日経平均は反落、後場下げ転換 国内機関投資家の売り観測も
# 38570    日経平均は小幅続落、持ち高整理の売り優勢 大引け前に下げ幅縮める
# 38381         日経平均は大幅続落で大引け、円高と米株安で手じまい売り
# 37748                日経平均は反発、円高一服で後場に買い戻し
# 37699      日経平均は円安進行で1万9000円台回復、東芝・タカタ株急落
# 37644           日経平均は3日続伸、円安・良好な中国経済指標が支援
# 37547        日経平均は反落、トランプ大統領の通商政策警戒し円高が進行
# 37502             日経平均は続落、円高が重し 先物主導で売られる
# 37444       日経平均は大幅反発、米国株高・円安好感し1万9000円回復
# 37337           日経平均は3日続伸、円安など外部環境良好でしっかり
# 36756                 日経平均は反落、主力輸出株が総じて軟調
# Name: title, dtype: object
#
# [event 1510]
# 38675                 日経平均は反発、1年ぶりに1万9500円台回復
# 38385          前場の日経平均は続落、下げ幅一時200円超 2週ぶり安値水準
# 38381             日経平均は大幅続落で大引け、円高と米株安で手じまい売り
# 38356          日経平均大引けは3日続落、年間では0.42％高と5年連続上昇
# 38290                 日経平均は大幅反発、大発会は終値で4年ぶり上昇
# 38241                    日経平均は反落、円高基調を嫌気し下げ転換
# 38194                   日経平均は続落、円高嫌気し輸出株が売られる
# 38109                       日経平均は3日続落、円高進行を嫌気
# 37823             日経平均は大幅続落、1万9000円割れ 1カ月ぶり安値
# 36805             日経平均は反発、終値は5営業日ぶり1万9000円台回復
# 36645    日経平均は続伸、日米首脳会談の無難通過で安心感 一時1万9500円台回復
# Name: title, dtype: object
#
# [event 1511]
# 38500           日経平均は3日続落、見送りムード優勢 日中値幅は今年最小
# 38463          日経平均は4日ぶり小反発、円相場弱含みで 売買高は膨らまず
# 38049    日経平均は4日ぶりに反発、外需株買い戻し トランプ会見前で様子見ムード
# Name: title, dtype: object
#
# [event 1514]
# 38932      焦点：米議会によるＦＲＢ改革論議、トランプ勝利で見直しも
# 38801    米新政権の税制改革、国境税調整案に批判 業界団体が議会に書簡
# 37712    米共和党幹部、国境税調整の必要性訴える トランプ氏の批判受け
# 37667          米財務長官候補、債務上限引き上げで早期対応求める
# 37161          米民主党、司法・財務・厚生長官の承認採決を先送り
# 37135     入国制限の米大統領令、身内共和党からも法整備の必要性問う声
# 36886      米最高裁判事に指名のゴーサッチ氏、民主党が独立性を疑問視
# Name: title, dtype: object
#
# [event 1515]
# 38823    焦点：「大き過ぎて潰せない」米中関係、トランプ戦略描く中国
# 38768       「一つの中国」見直し、両国関係に大きく影響＝オバマ氏
# Name: title, dtype: object
#
# [event 1519]
# 38680    フィリピン大統領、麻薬問題で中国非難は不公平と擁護
# 38359          米大使の大半はスパイ＝フィリピン大統領
# Name: title, dtype: object
#
# [event 1527]
# 12123    トランプ氏、国務長官にエクソンのティラーソン氏を指名へ 米報道
# 12114         トランプ氏、エクソンのティラーソン氏を国務長官に指名
# 38729          コラム：エクソンＣＥＯが米国務長官にふさわしい理由
# 11647    米国務長官候補のティラーソン氏、対ロシアで強硬姿勢 上院公聴会
# Name: title, dtype: object
#
# [event 1531]
# 38930      トランプ氏、ジンキ下院議員を次期内務長官に指名へ＝報道
# 38224     トランプ氏、米国家情報長官にコーツ前上院議員を指名の意向
# 11711     トランプ氏、米国家情報長官にダン・コーツ前上院議員を指名
# 38083    米公聴会、次期司法長官はクリントン氏の捜査に関与せずと表明
# Name: title, dtype: object
#
# [event 1535]
# 38926    大企業製造業の業況判断ＤＩ、6四半期ぶり改善＝12月日銀短観
# 38929      12月日銀短観は製造業で景況感改善、為替は円高方向に修正
# 38928            日銀短観、製造業の景況感改善：識者はこうみる
# 38921    日銀12月短観、景況感が1年半ぶり改善 米新政権の影響見極め
# Name: title, dtype: object
#
# [event 1536]
# 38925              寄り付きの日経平均は小幅続伸、年初来高値を更新
# 38919          前場の日経平均は7日ぶり反落、ポジション調整売りが優勢
# 38874             寄り付きの日経平均は続伸、ＴＯＰＩＸも年初来高値
# 38865          前場の日経平均は8日ぶり小反落、利益確定売りに押される
# 38827              寄り付きの日経平均は続伸、年初来高値を連日更新
# 38817         前場の日経平均は9日続伸、欧米株高好感し連日の年初来高値
# 38809      日経平均は9日続伸、欧米株高・円安を好感 連日の年初来高値更新
# 38747              寄り付きの日経平均は反落、主力株に利益確定売り
# 38751           前場の日経平均は反落、商い細り利益確定売りに押される
# 38701            寄り付きの日経平均は小幅続落、強含みの円相場が重し
# 38691              前場の日経平均は小幅続落、押し目買いで下げ渋る
# 38646             寄り付きの日経平均は続伸、年初来高値を連日で更新
# 38640              前場の日経平均は小幅続伸、買い先行後は伸び悩む
# 38602             寄り付きの日経平均は続落、米株安受け利益確定売り
# 38588          日経平均は続落、一時100円超安 押し目買いで下げ渋る
# 38518               寄り付きの日経平均は続落、円安一服で売り先行
# 38512              前場の日経平均は小幅続落、海外勢不在で売買低調
# 38480                 寄り付きの日経平均は続落、換金売りが優勢
# 38469                前場の日経平均は反発、円弱含みでプラス転換
# 38443             寄り付きの日経平均は小反落、押し目買いで底堅さも
# 38430              前場の日経平均は小幅続伸、押し目買い需要が多い
# 38399        寄り付きの日経平均は続落、米株安など嫌気し150円超す下げ
# 38366     寄り付きの日経平均は続落、1万9000円下回り3週ぶり安値水準に
# ...
# Name: title, dtype: object
#
# [event 3353]
# 37452               独社会民主党、シュルツ氏を首相候補に擁立
# 11400    独社民党の首相候補にシュルツ前欧州議会議長 メルケル氏の対抗馬
# Name: title, dtype: object
#
# [event 3355]
# 37455      トランプ政権が環境関連の政府機関にかん口令 意見封じ込めか
# 11393    トランプ政権、政府機関にかん口令 外部との接触や情報発信を制限
# Name: title, dtype: object
#
# [event 3380]
# 11253                  英下院、EU離脱通告法案を可決
# 36891             英議会、親ＥＵ派のＥＵ離脱法修正案を否決
# 36823     スコットランド議会、英ＥＵ離脱手続き開始の拒否議案を可決
# 36813    ＥＵ離脱の最終合意案、欧州議会送付前に英議会で採決＝英議員
# 15366         英ＥＵ離脱 下院が手続き開始法案可決、首相に権限
# 11107     英EU離脱、下院が通知法案を可決 来月の手続き開始へ前進
# Name: title, dtype: object
#
# [event 3381]
# 15448      イスラエル、入植者住宅２５００戸の建設を承認
# 15408    イスラエル、入植地でさらに３０００戸の住宅建設へ
# Name: title, dtype: object
#
# [event 3385]
# 37390              ＮＹダウ、史上初の2万ドル突破：識者はこうみる
# 37422        米国株は続伸、ダウは初の2万ドル突破 トランプ相場が再加速
# 37407    アングル：米ダウ2万ドル突破、1万ドル乗せから18年「異例の遅さ」
# 37370          焦点：ダウ2万ドルは通過点、先高期待続くも一部に警戒感
# Name: title, dtype: object
#
# [event 3400]
# 11332      米連邦裁、難民らの入国規制したトランプ大統領令を一部阻止
# 37293    移民制限の米大統領令、停止判断相次ぐ 当局「司法判断に従う」
# 37284    移民政策に関する米大統領令の実施、関心持ち見守る＝菅官房長官
# 37030     米マイクロソフト、移民入国制限に例外措置を要請 個々に判断
# 36684     米当局者「最高裁に上訴せず」、入国制限で新たな大統領令検討
# 11082         トランプ大統領、上訴せず入国禁止の新大統領令を検討
# Name: title, dtype: object
#
# [event 3405]
# 15403             欧州の極右勢力からは歓迎の声 米入国禁止措置
# 11276     米入国禁止令に航空業界も混乱、トランプ政権に「明確な説明を」
# 11268        トランプ氏の入国禁止令、米外交官多数が正規ルートで異議
# 11267    米IT勢、トランプ氏の入国禁止令に「共同戦線」 法的措置を協議
# 37044       トランプ氏、移民の入国制限は米国の宗教の自由に必要と説明
# 37030      米マイクロソフト、移民入国制限に例外措置を要請 個々に判断
# 36931        トランプ米大統領、入国制限めぐり判事や裁判所制度を批判
# 11190        足止めの移民ら、米入国急ぐ トランプ氏は連日の司法非難
# 11112    連邦判事は「政治的」 トランプ大統領、入国禁止令めぐり司法批判
# Name: title, dtype: object
#
# [event 3417]
# 36839    ティラーソン米国務長官が日韓豪と電話会談、関係強化の意向示す
# 36816     米トルコ首脳が電話会談、トランプ大統領はトルコを支援と表明
# 36716     米中首脳が電話会談、トランプ氏「１つの中国」政策維持で合意
# Name: title, dtype: object
#
# [event 3421]
# 37397    トランプ氏、シリアへの「安全地帯」設置に向け計画立案へ
# 37395       トランプ氏、シリアへの「安全地帯」設置の意向表明
# Name: title, dtype: object
#
# [event 3422]
# 37391        コラム：トランプ氏の「国境税」と「国境調整」の違いは
# 36946    米共和党幹部、国境税調整の内容修正へ 輸入関連企業の懸念考慮
# Name: title, dtype: object
#
# [event 3431]
# 37291     カナダ、米入国制限で足止めされた人に一時滞在許可へ＝移民相
# 37293    移民制限の米大統領令、停止判断相次ぐ 当局「司法判断に従う」
# 11317         米入国禁止で足止めの移民ら、一時滞在許可へ カナダ
# 37206          難民872人の米入国許可、大統領令後に＝内部資料
# Name: title, dtype: object
#
# [event 3433]
# 37244          豪との二重国籍保持者、米大統領令の適用除外＝首相
# 15427     トランプ米大統領の入国禁止措置、欧州の同盟国からも非難の声
# 11276    米入国禁止令に航空業界も混乱、トランプ政権に「明確な説明を」
# 11273        米入国禁止令への反発続く、国連総長や共和党議員も批判
# 11268       トランプ氏の入国禁止令、米外交官多数が正規ルートで異議
# Name: title, dtype: object
#
# [event 3434]
# 37223    入国制限の大統領令を擁護せず、合法との確信ない＝米司法長官代行
# 11112    連邦判事は「政治的」 トランプ大統領、入国禁止令めぐり司法批判
# 11082          トランプ大統領、上訴せず入国禁止の新大統領令を検討
# Name: title, dtype: object
#
# [event 3437]
# 37170           イスラム圏7カ国、近く米入国認可の可能性低く＝高官
# 37167    米入国制限のイスラム圏7カ国、近く入国認可される可能性低い＝高官
# 11268         トランプ氏の入国禁止令、米外交官多数が正規ルートで異議
# 11267     米IT勢、トランプ氏の入国禁止令に「共同戦線」 法的措置を協議
# 37097     トランプ米大統領、大手ＣＥＯらと3日に会合 入国制限で意見交換
# Name: title, dtype: object
#
# [event 3438]
# 37084    米永住権保有者、入国に大統領令の適用免除申請不要＝ホワイトハウス
# 37062      入国制限対象国の移民ビザ保有者、米地裁が「入国許可」の仮判断
# 11190         足止めの移民ら、米入国急ぐ トランプ氏は連日の司法非難
# Name: title, dtype: object
#
# [event 3453]
# 11384    水責めなどの拷問「効果ある」、トランプ大統領が見解示す
# 11358      マティス米国防長官は拷問禁止を支持、国防総省が発表
# Name: title, dtype: object
#
# [event 3459]
# 37341    ヨルダン国王、30日から米国訪問へ トランプ政権幹部と会談
# 37187      イスラエル首相が2月15日に訪米、トランプ大統領と会談
# Name: title, dtype: object
#
# [event 3460]
# 36951       米国防長官、尖閣の防衛義務を表明 安倍首相「日本は防衛力強化」
# 11213    マティス米国防長官、安倍首相と会談 「100パーセント、日本と協力」
# 15391        マティス米国防長官、「尖閣に日米安保適用」 稲田防衛相と会談
# 36965        米国防長官が中国非難、軍事行動は排除 日本に防衛負担増を示唆
# Name: title, dtype: object
#
# [event 3468]
# 37376    米アルファベット、10－12月調整後利益は予想下回る 株価下落
# 37081       米フェイスブック第4四半期は予想上回る、17年は投資拡大
# 37037            アマゾン、第1四半期は営業減益を予想 株価下落
# Name: title, dtype: object
#
# [event 3471]
# 37375               12月全国消費者物価は前年比-0.2％＝総務省
# 37361    消費者物価、12月は-0.2％ ガソリン上昇でマイナス幅縮小＝総務省
# Name: title, dtype: object
#
# [event 3472]
# 36894     訪日するＮＺ貿易相と会談、自由貿易について議論＝石原再生相
# 36895    日米首脳会談、通商ルール作成の提案は検討してない＝菅官房長官
# 36810    トランプ政権の理解得るよう努めていく＝米貿易赤字で菅官房長官
# Name: title, dtype: object
#
# [event 3478]
# 37360    米トランプ政権、ムスリム同胞団のテロ組織指定を検討＝関係筋
# 36818          米政府、イラン革命防衛隊のテロ組織指定を検討か
# Name: title, dtype: object
#
# [event 3483]
# 37355      トランプ氏、米最高裁判事の指名難航なら手続き改定も視野
# 37135    入国制限の米大統領令、身内共和党からも法整備の必要性問う声
# Name: title, dtype: object
#
# [event 3491]
# 37339    来週の東京株式市場は堅調地合い、主要企業の決算にらみで個別物色
# 37304       今週の日本株は堅調地合い、主要企業の決算にらみで個別物色
# Name: title, dtype: object
#
# [event 3492]
# 37275     日経平均は4日ぶり反落、トランプ米大統領の政策に警戒も
# 37203          日経平均は327円安、米政権を巡る混乱を嫌気
# 37131               日経平均は反発、円高一服で買い戻し
# 37069    日経平均は大幅反落、一時280円超安 前日の上昇帳消しに
# 36926             日経平均は続伸、円高警戒で上値重い展開
# 36866           日経平均は反落、円高進行で自動車株など軟調
# Name: title, dtype: object
#
# [event 3497]
# 37336         ドイツ首相が来週2日トルコ訪問、大統領と会談
# 37187    イスラエル首相が2月15日に訪米、トランプ大統領と会談
# Name: title, dtype: object
#
# [event 3512]
# 37326    米英首脳が会談、トランプ氏「絆新たに」 通商協定など協議
# 15435       米英首脳、関係強化で一致 トランプ氏が国賓で訪英へ
# Name: title, dtype: object
#
# [event 3515]
# 37309    ドル買われ115円前半に上昇、トランプ政策期待根強く＝ＮＹ市場
# 37239     ドルが対円で下落、113円台 米入国制限の混乱受け＝ＮＹ市場
# 36977    ドル112円後半、雇用統計受け目先の米利上げ観測後退＝ＮＹ外為
# 36901     ユーロが対ドル下落、1週間ぶり安値 仏大統領選懸念＝ＮＹ市場
# 36844     ドル上昇、欧州政治に不透明感 値ごろ感からの買いも＝ＮＹ市場
# Name: title, dtype: object
#
# [event 3516]
# 37312    米国株式市場は軟調、ＧＤＰや企業決算さえず
# 36796    米国株はまちまち、ダウは反落 金融株が安い
# Name: title, dtype: object
#
# [event 3521]
# 37151    日本はＧ７やＧ２０の合意に沿った政策進めている＝為替で官房長官
# 37125     為替含む経済・貿易で日米の意思疎通図ることが大事＝菅官房長官
# Name: title, dtype: object
#
# [event 3522]
# 36996      中国外務省「通貨戦争望まず」、トランプ大統領に反論
# 36893    為替は市場で決まる話、日本の通貨政策は適切＝麻生財務相
# 36698    公平な対中貿易競争環境、トランプ氏「かなり早く実現へ」
# Name: title, dtype: object
#
# [event 3523]
# 11355            DVの罰則を軽減する法改正案、ロシア下院で可決
# 11133    プーチン大統領、DVの罰則を軽減する改正案に署名 正式に法制化
# Name: title, dtype: object
#
# [event 3530]
# 11346    ギリシャの対外債務、「非常に危険な状態」になる恐れも IMF
# 37020      焦点：保護主義的な米税制改革、国際ルール違反の可能性高く
# Name: title, dtype: object
#
# [event 3542]
# 11351      トランプ氏の大統領令、各地で影響 米空港での拘束や搭乗拒否
# 15431       イスラム教徒受け入れ停止、国内外に衝撃 トランプ氏は自賛
# 11298    空港混乱「デモのせい」 トランプ大統領、入国禁止令の批判に反論
# 11180           トランプ大統領の入国禁止令、欧州各地で大規模デモ
# 11177      米各地でトランプ大統領の入国禁止令に抗議、移民への連帯示す
# 15373       ノルウェー元首相も空港で１時間足止め、イランのビザが原因
# Name: title, dtype: object
#
# [event 3543]
# 37276    日航、イスラム圏7カ国の旅客の米入国可否を米当局に照会
# 37253     日航と全日空、イスラム圏7カ国の旅客の米入国可否確認
# Name: title, dtype: object
#
# [event 3545]
# 11313     全米各地で抗議デモ、トランプ大統領の入国制限令で混乱続く
# 11177    米各地でトランプ大統領の入国禁止令に抗議、移民への連帯示す
# Name: title, dtype: object
#
# [event 3549]
# 11292    トランプ大統領、入国禁止令を擁護しないよう指示した司法省トップを解任
# 11276        米入国禁止令に航空業界も混乱、トランプ政権に「明確な説明を」
# 11273            米入国禁止令への反発続く、国連総長や共和党議員も批判
# 11268           トランプ氏の入国禁止令、米外交官多数が正規ルートで異議
# 11267       米IT勢、トランプ氏の入国禁止令に「共同戦線」 法的措置を協議
# 11208       トランプ大統領、入国禁止差し止めた判事に暴言 司法の独立に暗雲
# 11188            トランプ政権、入国禁止の大統領令差し止めに控訴手続き
# 11180              トランプ大統領の入国禁止令、欧州各地で大規模デモ
# 11177         米各地でトランプ大統領の入国禁止令に抗議、移民への連帯示す
# Name: title, dtype: object
#
# [event 3552]
# 37277      米大統領と韓国大統領代行、北朝鮮の脅威に連携強化で合意
# 11303    トランプ氏と韓国大統領代行が電話会談、対北防衛の強化で合意
# 37199     米韓、対北朝鮮防衛の連携強化で合意 国防トップが電話会談
# Name: title, dtype: object
#
# [event 3555]
# 11326    イスラエル首相、トランプ大統領の「壁建設」をツイッターで称賛
# 37258         メキシコ、イスラエル首相の「壁」称賛ツイートを非難
# Name: title, dtype: object
#
# [event 3558]
# 15419       マレーシア沖で船が沈没、中国人観光客ら３１人が乗船
# 15422    マレーシア沖で船沈没、３人死亡 中国人観光客ら３１人乗船
# Name: title, dtype: object
#
# [event 3560]
# 37284    移民政策に関する米大統領令の実施、関心持ち見守る＝菅官房長官
# 11314          トランプ氏の入国禁止令、米外交官「数百人」が異議
# 11276    米入国禁止令に航空業界も混乱、トランプ政権に「明確な説明を」
# 11273        米入国禁止令への反発続く、国連総長や共和党議員も批判
# 11268       トランプ氏の入国禁止令、米外交官多数が正規ルートで異議
# 11258              米入国禁止令は「誤り」 メイ英首相が批判
# Name: title, dtype: object
#
# [event 3570]
# 36694       トランプ氏「日本の安全保障にコミット」、強硬姿勢封印
# 36688    日米対話強化で新枠組み、尖閣は安保適用対象と確認＝安倍首相
# Name: title, dtype: object
#
# [event 3571]
# 37303     今週の米株式市場はＦＯＭＣや1月米雇用統計に注目
# 36968    今週の米株は大企業決算に注目、ドル安で見通し改善も
# Name: title, dtype: object
#
# [event 3573]
# 36689        トランプ氏が新たな安全保障措置、来週の導入方針表明
# 36684    米当局者「最高裁に上訴せず」、入国制限で新たな大統領令検討
# Name: title, dtype: object
#
# [event 3577]
# 36903    独選挙、中道左派ＳＰＤがメルケル氏の保守派破る勢い＝調査
# 36824    独紙「メルケル首相に嫌気か」、ＳＰＤが支持率で保守派抜く
# Name: title, dtype: object
#
# [event 3579]
# 37289    15の州司法長官ら、移民制限の米大統領令非難 法的措置も検討
# 37293    移民制限の米大統領令、停止判断相次ぐ 当局「司法判断に従う」
# Name: title, dtype: object
#
# [event 3591]
# 15424          モスクでの銃撃で死傷者、１人逮捕 カナダ
# 15420    カナダのイスラム教施設銃撃、６人死亡 テロとして捜査
# Name: title, dtype: object
#
# [event 3594]
# 37262    安倍首相がトヨタ社長と今週会談へ、対米対応で協議か＝関係筋
# 36952        安倍首相、トヨタ社長と会談 貿易摩擦回避へ対応協議
# Name: title, dtype: object
#
# [event 3598]
# 37230    焦点：国境調整税で消費者にしわ寄せも、製油業者への打撃通じ
# 37186     焦点：自動車標的のトランプ戦術、日本の生産・輸出に打撃も
# Name: title, dtype: object
#
# [event 3599]
# 37272     米富豪コーク氏の政治団体、共和党国境税案の阻止目指す
# 37100    米共和党2議員、デボス氏の教育長官承認に本会議で反対へ
# Name: title, dtype: object
#
# [event 3600]
# 37264          大和の16年10─12月期当期利益は266億円、投信から資金流出
# 37183             野村の16年10─12月期は当期利益が倍増、収益構造に変化
# 37179    コマツの16年4─12月期は31％の営業減益 産機収益減で通期予想は据え置き
# 37191         みずほの4―12月期当期利益は‐2.8％、マイナス金利の影響などで
# Name: title, dtype: object
#
# [event 3607]
# 11324    バノン首席戦略官、NSCの常任メンバーに トランプ大統領が命じる
# 11204    「なぜバノン氏をNSC常任に」米民主議員50人、大統領に説明要求
# Name: title, dtype: object
#
# [event 3610]
# 11301        「ワレサ氏はスパイだった」 検察が筆跡による証拠提示へ
# 11269    ノーベル賞のワレサ氏「筆跡鑑定でスパイと証明」 ポーランド検察
# 11120     ノーベル賞受賞者のワレサ氏、スパイ疑惑を全面否定 ポーランド
# Name: title, dtype: object
#
# [event 3618]
# 11305    物置小屋のパーティーで若者6人死亡、一酸化炭素中毒か 独
# 11270    物置小屋で死亡した若者6人、死因は一酸化炭素中毒 独警察
# Name: title, dtype: object
#
# [event 3620]
# 11255    米入国禁止令「テロリスト排除では無効果」国連トップが解除要請
# 37030     米マイクロソフト、移民入国制限に例外措置を要請 個々に判断
# Name: title, dtype: object
#
# [event 3621]
# 11225         米国、6万人のビザ取り消し トランプ氏の入国禁止令で
# 11208    トランプ大統領、入国禁止差し止めた判事に暴言 司法の独立に暗雲
# 11190        足止めの移民ら、米入国急ぐ トランプ氏は連日の司法非難
# 36710    入国制限巡る米控訴裁決定は政治的、最後は政権が勝利＝トランプ氏
# Name: title, dtype: object
#
# [event 3626]
# 11310    麻薬撲滅戦争を任期終了まで継続、一方で警察の腐敗を批判 比大統領
# 11229       麻薬撲滅戦争を軍主導に 比大統領、中毒者のさらなる殺害誓う
# Name: title, dtype: object
#
# [event 3631]
# 37175    米国株式市場はダウとＳ＆Ｐ５００種が続落、低調な企業決算が重し
# 37102         ダウとＳ＆Ｐが反発、アップル株買われ主要指数押し上げ
# Name: title, dtype: object
#
# [event 3633]
# 37246    トランプ氏、規制緩和で大統領令 金融規制改革法には踏み込まず
# 36975       トランプ氏、金融規制改革法の大統領令に署名 見直し指示
# 11216        トランプ大統領、金融改革の見直し指示 規制緩和へ始動
# Name: title, dtype: object
#
# [event 3636]
# 37241    米外交官が入国制限の大統領令を批判、国務省でメモを回覧
# 37156       米入国制限令、国務省職員約900人が抗議＝関係筋
# Name: title, dtype: object
#
# [event 3640]
# 37121    コラム：トランプ政権「次の標的」は日本か＝佐々木融氏
# 36575     コラム：日米経済対話で開く「円高の扉」＝佐々木融氏
# Name: title, dtype: object
#
# [event 3649]
# 37209         イラン、中距離弾道ミサイルの発射実験＝米当局者
# 15368    イラン、地対空ミサイルの発射実験 安保理決議には違反せず
# Name: title, dtype: object
#
# [event 3650]
# 37092     イラン「核合意に違反せず」、弾道ミサイル発射実験認める
# 15368    イラン、地対空ミサイルの発射実験 安保理決議には違反せず
# Name: title, dtype: object
#
# [event 3651]
# 37201    米ハイテク企業、入国制限令めぐる裁判で法廷助言書の提出検討へ
# 36923     移民制限の米大統領令、約100社が反対意見書を控訴裁に提出
# Name: title, dtype: object
#
# [event 3652]
# 36854          米入国制限差し止め、連邦控訴裁で7日に口頭弁論
# 11158        入国禁止令、米司法省が高裁に申し立て あす口頭弁論
# 36821     「差し止めは誤り」入国制限巡り米政権、控訴裁が週内に判断
# 36713    米控訴裁は入国制限差し止め支持、トランプ氏「法廷で会おう」
# Name: title, dtype: object
#
# [event 3655]
# 37215         金相場が上昇、米大統領の政策受け安全資産求める動き
# 37133    日米会談で財務相が政策説明へ、通貨安批判受け 為替の安定重要
# Name: title, dtype: object
#
# [event 3656]
# 11294            イラン、ミサイル実験を実施 米政府が確認
# 11250     イラン、ミサイル発射実験の実施認める 核合意違反は否定
# 37077    トランプ政権、イランに「警告」 ミサイル実験受け対応検討
# 15368    イラン、地対空ミサイルの発射実験 安保理決議には違反せず
# Name: title, dtype: object
#
# [event 3659]
# 37158            みずほ銀行頭取に藤原常務、生産性の向上が課題
# 37173    アングル：みずほ銀、藤原次期頭取に問われるカンパニー制の成果
# Name: title, dtype: object
#
# [event 3662]
# 37202       「日米イニシアチブ」検討、数十万人の米雇用増目指す＝政府筋
# 37028    4500億ドルの市場・70万人の雇用創出効果、米に表明へ＝政府筋
# Name: title, dtype: object
#
# [event 3664]
# 37194      キヤノン17年度は3年ぶり増益予想、医療機器事業買収の効果
# 37110    日立の通期営業利益5600億円の予想、円安寄与し200億円増額
# 37058    ソニーが利益予想を下方修正、映画事業で巨額減損 事業売却は否定
# 36648       サッポロＨＤ、今期は5％営業増益計画 食品や不動産が貢献
# Name: title, dtype: object
#
# [event 3666]
# 36925    スズキの4─12月期営業益は前年比14.4％増、インド・欧州の販売好調
# 36743      日産の4─12月営業益は前年比14％減、円高が逆風 通期は据え置き
# Name: title, dtype: object
#
# [event 3667]
# 37061    マツダ、今期営業益1300億円に下方修正 日米販売不振と品質費用
# 36790         ＪＤＩ業績回復基調、3年ぶり最終黒字化に会長「手応え」
# Name: title, dtype: object
#
# [event 3669]
# 37181    任天堂が最終益予想を上方修正、想定為替修正で 営業益は引き下げ
# 37054       パナソニックが通期予想を上方修正、米当局調査は言及避ける
# Name: title, dtype: object
#
# [event 3670]
# 37182      三菱自が今期営業黒字へ、採算改善と円安で赤字予想から一転
# 37072    三菱電機、通期業績予想を上方修正 為替前提を円安方向に見直し
# Name: title, dtype: object
#
# [event 3671]
# 37058    ソニーが利益予想を下方修正、映画事業で巨額減損 事業売却は否定
# 37066      新日鉄住金、今期純利益予想を上方修正 関連会社の損益が好転
# Name: title, dtype: object
#
# [event 3679]
# 37177    ユーロ「過小評価」、ドイツ有利な立場に─米通商会議トップ＝ＦＴ
# 36843      米政権、ドル高の要因は自国にあると認識する必要＝独連銀総裁
# 36758       中曽副総裁、日銀の金融緩和は為替目的ではない 各国も理解
# Name: title, dtype: object
#
# [event 3692]
# 37129        サンフランシスコ市がトランプ氏提訴、大統領令「違憲で非米国的」
# 11274    「聖域都市」サンフランシスコ市が提訴、トランプ氏の大統領令差し止め求め
# 36931            トランプ米大統領、入国制限めぐり判事や裁判所制度を批判
# 36923          移民制限の米大統領令、約100社が反対意見書を控訴裁に提出
# 11170           米大手IT企業、トランプ大統領令への対抗訴訟を連合で支援
# Name: title, dtype: object
#
# [event 3702]
# 37146      米最高裁判事に保守派ゴーサッチ氏、トランプ大統領が指名
# 11265    トランプ大統領、最高裁判事にゴーサッチ氏指名 保守派優位に
# 37115    焦点：米最高裁判事指名のゴーサッチ氏、政府の法権限に懐疑的
# Name: title, dtype: object
#
# [event 3715]
# 37134    米国防長官、日韓訪問で米の役割強調へ 中国・北朝鮮情勢にらむ
# 37093       独政府報道官、トランプ政権との協力は「始まったばかり」
# Name: title, dtype: object
#
# [event 3721]
# 37118    韓国大統領選、潘基文氏が出馬見送り表明
# 11249      潘基文氏、韓国大統領選不出馬を表明
# Name: title, dtype: object
#
# [event 3723]
# 37120    ロシュ、2016年通期コア利益は7％増 予想やや下回る
# 37119        ジュリアス・ベア、16年の実質利益が予想上回る
# Name: title, dtype: object
#
# [event 3724]
# 36640    中国、北朝鮮のミサイル実験非難 「国連決議に違反」
# 36638      ロシア、北朝鮮のミサイル実験に懸念表明＝通信社
# Name: title, dtype: object
#
# [event 3731]
# 11264    米政府、ビザ申請者のSNS履歴と通話記録の開示求める可能性示唆
# 11267    米IT勢、トランプ氏の入国禁止令に「共同戦線」 法的措置を協議
# 11135       イスラム圏のビザ申請者、SNSパスワード提出義務化か 米
# Name: title, dtype: object
#
# [event 3737]
# 11254    政府軍と親ロシア派の戦闘、3日間で13人死亡 ウクライナ
# 15402               ウクライナ東部で戦闘再燃、死傷者も
# Name: title, dtype: object
#
# [event 3745]
# 37107    英下院、ＥＵ離脱通知の承認求める法案可決 審議は次の段階へ
# 15414          ＥＵ離脱へ前進、下院が手続き開始法案を承認 英
# 36891             英議会、親ＥＵ派のＥＵ離脱法修正案を否決
# Name: title, dtype: object
#
# [event 3750]
# 37078    インフラ投資通じた経済協力の報道、そのような事実ない＝ＧＰＩＦ
# 36878      ＧＰＩＦ投資、首相「指図できない」 米インフラ巡る報道否定
# Name: title, dtype: object
#
# [event 3754]
# 37082    豪貿易黒字、12月は過去最大の35.11億豪ドル 輸出も過去最高
# 36744      独貿易黒字、2016年は過去最高更新 米国との摩擦高まる恐れ
# 36728            中国の対米貿易黒字、1月は213.7億ドルに縮小
# 36463       中国1月対外投資は36％減、資本流出規制で不動産投資が減少
# Name: title, dtype: object
#
# [event 3775]
# 15366        英ＥＵ離脱 下院が手続き開始法案可決、首相に権限
# 11107    英EU離脱、下院が通知法案を可決 来月の手続き開始へ前進
# Name: title, dtype: object
#
# [event 3784]
# 37049     中国の資本純流出、16年は7250億ドルと過去最高＝ＩＩＦ
# 36744    独貿易黒字、2016年は過去最高更新 米国との摩擦高まる恐れ
# 36728          中国の対米貿易黒字、1月は213.7億ドルに縮小
# 36463     中国1月対外投資は36％減、資本流出規制で不動産投資が減少
# Name: title, dtype: object
#
# [event 3786]
# 36552    米大統領、ロシア巡るフリン氏の説明不完全と以前から把握＝報道官
# 11004      対ロ協議疑惑、トランプ氏が1月に問題把握 フリン氏は訴追も
# Name: title, dtype: object
#
# [event 3801]
# 37034         米、イラン新制裁実施へ ミサイル実験受け＝関係筋
# 36825    米・イスラエルが15日に首脳会談、イランへの圧力強化目指す
# Name: title, dtype: object
#
# [event 3814]
# 37008       北朝鮮、国家保衛相を解任か＝韓国統一省
# 15395    北朝鮮、国家安全保衛相を解任 金委員長の側近
# Name: title, dtype: object
#
# [event 3816]
# 37013    ＹＣＣは財政ファイナンスでない、物価2％を早期に実現＝日銀総裁
# 36770     中曽日銀副総裁、長期金利「ゼロ％程度」堅持の構え 春闘に期待
# 36758       中曽副総裁、日銀の金融緩和は為替目的ではない 各国も理解
# Name: title, dtype: object
#
# [event 3820]
# 36999         日経平均は小反発、日銀「指値オペ」後の円安でプラス転換
# 36962    今日の株式見通し＝続伸、日経平均1万9000円回復後は為替にらみ
# 36926                 日経平均は続伸、円高警戒で上値重い展開
# 36866               日経平均は反落、円高進行で自動車株など軟調
# 36846          今日の株式見通し＝反発、米国株高と円高一服で買い先行
# 36712           日経平均は急反発、米税制改革期待と円安で471円高
# Name: title, dtype: object
#
# [event 3827]
# 36992       三菱ＵＦＪ、4―12月期の当期利益‐7％ 進ちょく率は92.5％
# 36925    スズキの4─12月期営業益は前年比14.4％増、インド・欧州の販売好調
# 36743      日産の4─12月営業益は前年比14％減、円高が逆風 通期は据え置き
# Name: title, dtype: object
#
# [event 3829]
# 36988    欧州委員、トランプ大統領の「分割統治」を批判
# 36672    英離脱交渉、ＥＵを分裂させる恐れ＝欧州委員長
# Name: title, dtype: object
#
# [event 3830]
# 36989    ロシア、虚偽を武器に西側諸国の弱体化狙う＝ファロン英国防相
# 36871    トランプ氏、「欧州全域」の過激派攻撃を報道していないと非難
# Name: title, dtype: object
#
# [event 3833]
# 11215               米、弾道ミサイル実験でイランに追加制裁
# 11201    イラン、軍事演習にミサイル配備 追加制裁科した米への抗議表明
# Name: title, dtype: object
#
# [event 3834]
# 36993     パリのルーブル美術館に刃物男、兵士が発砲
# 11227    仏ルーブル美術館で刃物男が襲撃、兵士が発砲
# Name: title, dtype: object
#
# [event 3836]
# 36984        東芝、英とインドの原発事業への関与縮小を検討＝関係筋
# 36399    インド、米ＷＨからの原子炉購入計画を継続 東芝問題の影響限定
# Name: title, dtype: object
#
# [event 3843]
# 36982    ユーロ「過小評価」批判、ドイツ財務相が反論
# Name: title, dtype: object
#
# [event 3845]
# 36956    年内2度の米利上げ予想変わらず、雇用統計受け＝短期先物
# Name: title, dtype: object
#
# [event 3851]
# 11211    トップレス姿の女性3人が警官と口論、大きな騒ぎに アルゼンチン
# 11110     トップレス禁止に抗議！上半身裸の女性たちがデモ アルゼンチン
# Name: title, dtype: object
#
# [event 3860]
# 36950    米国株は上昇、雇用統計や金融規制緩和に向けた大統領令が追い風
# Name: title, dtype: object
#
# [event 3870]
# 11202    ミャンマー軍がロヒンギャ迫害で「民族浄化」か、国連報告書
# 15398     ミャンマー軍、少数派ロヒンギャへ残虐行為か 国連報告書
# Name: title, dtype: object

# %%
len([x for x in chains if len(x) > 0])
# Out:
# 102

# %%
for i in range(100,100+200):
    print(i)
# Out:
# 100
# 101
# 102
# 103
# 104
# 105
# 106
# 107
# 108
# 109
# 110
# 111
# 112
# 113
# 114
# 115
# 116
# 117
# 118
# 119
# 120
# 121
# 122
# 123
# 124
# 125
# 126
# 127
# 128
# 129
# 130
# 131
# 132
# 133
# 134
# 135
# 136
# 137
# 138
# 139
# 140
# 141
# 142
# 143
# 144
# 145
# 146
# 147
# 148
# 149
# 150
# 151
# 152
# 153
# 154
# 155
# 156
# 157
# 158
# 159
# 160
# 161
# 162
# 163
# 164
# 165
# 166
# 167
# 168
# 169
# 170
# 171
# 172
# 173
# 174
# 175
# 176
# 177
# 178
# 179
# 180
# 181
# 182
# 183
# 184
# 185
# 186
# 187
# 188
# 189
# 190
# 191
# 192
# 193
# 194
# 195
# 196
# 197
# 198
# 199
# 200
# 201
# 202
# 203
# 204
# 205
# 206
# 207
# 208
# 209
# 210
# 211
# 212
# 213
# 214
# 215
# 216
# 217
# 218
# 219
# 220
# 221
# 222
# 223
# 224
# 225
# 226
# 227
# 228
# 229
# 230
# 231
# 232
# 233
# 234
# 235
# 236
# 237
# 238
# 239
# 240
# 241
# 242
# 243
# 244
# 245
# 246
# 247
# 248
# 249
# 250
# 251
# 252
# 253
# 254
# 255
# 256
# 257
# 258
# 259
# 260
# 261
# 262
# 263
# 264
# 265
# 266
# 267
# 268
# 269
# 270
# 271
# 272
# 273
# 274
# 275
# 276
# 277
# 278
# 279
# 280
# 281
# 282
# 283
# 284
# 285
# 286
# 287
# 288
# 289
# 290
# 291
# 292
# 293
# 294
# 295
# 296
# 297
# 298
# 299
