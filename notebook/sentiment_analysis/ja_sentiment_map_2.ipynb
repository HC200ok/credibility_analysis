# %%
import pandas as pd
import numpy as np
from keras.models import load_model
from keras.preprocessing.sequence import pad_sequences
from gmplot import gmplot
import pickle

emotions = ["happy", "sad", "disgust", "angry", "fear", "surprise"]
colors = ["orange", "blue", "green", "red", "gray", "purple"]

model = load_model("models/ja_tweets_sentiment/model_2018-08-28-15:00.h5")

with open("models/ja_tweets_sentiment/tokenizer_cnn_ja.pkl", "rb") as f:
    tokenizer = pickle.load(f)
    
def preprocess(data, tokenizer, maxlen=280):
    return(pad_sequences(tokenizer.texts_to_sequences(data), maxlen=maxlen))
# Out:
# Using TensorFlow backend.

# %%
import json
data = None
for i in range(1453):
    with open("tweets/data_{}.json".format(i)) as f:
        if data is None:
            data = json.load(f)
        else:
            data['statuses'] += json.load(f)['statuses']

# %% [markdown]
# 1. 市, 県, スペース, ,でsplit
# 2. lower
# 3. どれかが市名辞書に引っかかれば、最初に引っかかったものをリターン
# 4. 市名辞書に引っかからなければ県名辞書で引っかかったものをリターン
# 5. どれにもひっかからなければ無視

# %%
import pickle
with open("pref_dict.pkl", "rb") as f:
    pref_dict = pickle.load(f)
    
with open("city_dict.pkl", "rb") as f:
    city_dict = pickle.load(f)

# %%
import re
regex = r"[都道府県\,市町村群 ]"

def geocode(location, regex, city_dict, pref_dict):
    for d in re.split(regex, location):
        if d in city_dict:
            return city_dict[d]
        elif d in pref_dict:
            return pref_dict[d]
        else:
            return False

def format_data(statuses):
    results = []
    for status in statuses:
        try:
            coordinates = geocode(status['user']['location'], regex, city_dict, pref_dict)
            if coordinates:
                results.append({
                    'user':status['user']['screen_name'], 
                    'text':status['full_text'], 
                    'coordinates': coordinates,
                    'date': status['created_at']
                })
            else:
                continue
        except Exception as e:
            print(e)
            break
    return pd.DataFrame(results)

sample_size = 100000
df = format_data(data['statuses'])
df = df.sample(sample_size)
del(data)

# %%
df.head()
# Out:
#                                      coordinates  \
# 216397                     (35.85718, 139.65079)
# 42914                      (35.44771, 139.64256)
# 89447   (36.595240000000004, 136.62566999999999)
# 26719             (40.82516, 140.73976000000002)
# 36517              (35.6895, 139.69163999999998)
#
#                                   date  \
# 216397  Mon Aug 27 10:34:47 +0000 2018
# 42914   Tue Aug 28 12:17:21 +0000 2018
# 89447   Mon Aug 27 22:19:43 +0000 2018
# 26719   Tue Aug 28 23:00:55 +0000 2018
# 36517   Tue Aug 28 14:02:33 +0000 2018
#
#                                                      text             user  \
# 216397                               さくらももこさんご冥福をお祈りいたします        omu_musou
# 42914   RT @jbot26830444: 2018年亡くなった有名人\n\nさくらももこ(漫画家)...      Keitore7000
# 89447   RT @ribon60th: 【さくらももこさんご逝去の報】「ちびまる子ちゃん」の原作者であ...       HosiHukusu
# 26719   RT @COCHAE: さくらももこ先生、伝統こけしの世界にも大きな大きな力をくださいました...    tsugirl_junne
# 36517   RT @kazutan_1220: さくらももこさんの訃報を聞いた後に、初代OPだった「ゆめ...  greensilverBear
#
#         strength  emotion
# 216397  0.203490        1
# 42914   0.070822        4
# 89447   0.081132        1
# 26719   0.453150        4
# 36517   0.165295        4

# %%
preds = model.predict(preprocess(df['text'].tolist(), tokenizer))
strength = list(map(max, preds))
df['strength'] = strength
preds = np.argmax(preds, axis=1)
df['emotion'] = preds

# %%
df.to_csv("data.csv", index=False)

# %%
df = df.sample(10000)

# %%
from random import random
import math
from math import sqrt
from collections import namedtuple

def plot_gmap(data, colors, symbol="o", center=(38, 137, 6), size_param=(500, 1000), outfile="my_map.html"):
    gmap = gmplot.GoogleMapPlotter(*center)
    Symbol = namedtuple('Symbol', ['symbol', 'lat', 'long', 'size'])
    for i,d in data.iterrows():
        lat, lon = d['coordinates']
        if isinstance(lat, float) and isinstance(lon, float) and not math.isnan(lat) and not math.isnan(lon):
            lat, lon = lat+(random()-0.5)/2, lon+(random()-0.5)/2
            size = size_param[0]+size_param[1]*d['strength']**sqrt(2)
            settings = {"radius": size, "color": colors[d['emotion']], "marker": False, "face_alpha": 0.2}
            gmap.circle(lat,lon, **settings)
    gmap.draw(outfile)
    return gmap

# %%
gmap = plot_gmap(df, colors, size_param=(3000, 20000), outfile="momoko.html")

# %%
import math
math.isnan(tmp[0])
# Out:
# True

# %%
tmp = df.iloc[23]['coordinates']

# %%
df = df.dropna()

# %%
df.head(100)
# Out:
#                         coordinates  \
# 0     (35.6895, 139.69163999999998)
# 1             (34.97683, 138.38315)
# 2   (38.268390000000004, 140.87212)
# 3             (34.97683, 138.38315)
# 4             (34.97683, 138.38315)
# 5     (35.6895, 139.69163999999998)
# 6             (36.34404, 140.44547)
# 7             (35.85718, 139.65079)
# 8             (34.68635, 135.52043)
# 9             (37.90246, 139.02341)
# 10            (37.75091, 140.46786)
# 11            (34.69119, 135.18311)
# 12   (35.18094, 136.90653999999998)
# 13            (34.69119, 135.18311)
# 14    (34.3966, 132.45833000000002)
# 15    (34.3966, 132.45833000000002)
# 16    (35.6895, 139.69163999999998)
# 17            (35.00379, 135.86783)
# 18    (35.6895, 139.69163999999998)
# 19            (34.97683, 138.38315)
# 20            (35.44318, 139.63734)
# 21    (35.6895, 139.69163999999998)
# 22    (35.6895, 139.69163999999998)
# 23                       (nan, nan)
# 24            (43.06411, 141.34702)
# 25            (34.97683, 138.38315)
# 26   (35.18094, 136.90653999999998)
# 27            (33.60648, 130.41812)
# 28            (39.70304, 141.15271)
# 29            (35.44771, 139.64256)
# ..                              ...
# 70            (37.75091, 140.46786)
# 71            (34.97683, 138.38315)
# 72            (34.58468, 133.77176)
# 73            (43.06411, 141.34702)
# 74            (34.97683, 138.38315)
# 75   (35.18094, 136.90653999999998)
# 76  (34.065490000000004, 134.56003)
# 77    (35.6895, 139.69163999999998)
# 78    (35.6895, 139.69163999999998)
# 79            (43.06411, 141.34702)
# 80    (35.6895, 139.69163999999998)
# 81    (35.6895, 139.69163999999998)
# 82            (34.97683, 138.38315)
# 83            (37.90246, 139.02341)
# 84            (33.84174, 132.76622)
# 85    (35.6895, 139.69163999999998)
# 86            (37.90246, 139.02341)
# 87            (35.44771, 139.64256)
# 88            (35.44771, 139.64256)
# 89            (37.75091, 140.46786)
# 90             (26.2133, 127.67963)
# 91            (34.18435, 131.47095)
# 92    (35.6895, 139.69163999999998)
# 93            (34.68635, 135.52043)
# 94  (36.064840000000004, 136.22145)
# 95            (40.72785, 141.25664)
# 96            (37.90246, 139.02341)
# 97            (35.60456, 140.12311)
# 98    (35.6895, 139.69163999999998)
# 99            (34.68635, 135.52043)
#
#                                                  text             user  \
# 0   【試合結果】\nさくらももこさん悼み喪章をつけてピッチへ…清水が横浜FM下し6試合ぶりの白星...     SoccerKingJP
# 1   【横浜F・マリノス戦 試合終了】\n清水 2-1 横浜FM\n応援してくださった皆様、\nそ...  spulse_official
# 2   RT @mollichane: さくらももこさんが亡くなって日が浅いので言いたくなかったけど...  BreakerMidorima
# 3   RT @mollichane: さくらももこさんが亡くなって日が浅いので言いたくなかったけど...       mazda2desu
# 4   RT @mollichane: さくらももこさんが亡くなって日が浅いので言いたくなかったけど...         fomal373
# 5   RT @comecaML: 西原理恵子が自作の中で、「さくらももこに無いダークさが自分にはあ...    akiyamayasumi
# 6   RT @Isseki3: ヘビースモーカーのさくらももこさんはタバコに殺された(乳癌の発症率...         ITF_QSYS
# 7   RT @monokirk: さくらももこくらい有名な作家で、文章でマンガで何度も自分のエピソ...           yone51
# 8   相互フォローありがとうございます～！\nさくらももこさんは国民的作家さんですね！\n\n#相...         sugumika
# 9   RT @mollichane: さくらももこさんが亡くなって日が浅いので言いたくなかったけど...            qoo09
# 10  RT @hukushima_tomio: おはようございます！今日1日があなたにとって、とっ...  erminiaboniface
# 11  RT @Eiichiro_Staff: さくらももこ先生ご逝去に際し、尾田さんより追悼イラス...       FPSboy0406
# 12  RT @mollichane: さくらももこさんが亡くなって日が浅いので言いたくなかったけど...      kingdyamond
# 13  RT @mollichane: さくらももこさんが亡くなって日が浅いので言いたくなかったけど...      water_fox76
# 14  RT @monokirk: さくらももこくらい有名な作家で、文章でマンガで何度も自分のエピソ...        gishigaku
# 15  RT @monokirk: どれひとつとしてさくらももこ自ら散々語ってきている話と合致してい...        gishigaku
# 16  RT @mollichane: さくらももこさんが亡くなって日が浅いので言いたくなかったけど...       manngakaki
# 17  RT @OPcom_info: さくらももこ先生ご逝去に際し、尾田先生より追悼イラストが届き...         makiyuno
# 18  RT @sayoriNikki: 西原理恵子がさくらももこと似ているだなんて、流石にさくらも...      teruteru21c
# 19  @Sakitagawa34 おはさよ〜*\(^o^)/* 昨日はさくらももこさんのおくやみの...    tuituitwittar
# 20  RT @mollichane: さくらももこさんが亡くなって日が浅いので言いたくなかったけど...         Hati_gin
# 21  RT @mollichane: さくらももこさんが亡くなって日が浅いので言いたくなかったけど...            aaagn
# 22  RT @mollichane: さくらももこさんが亡くなって日が浅いので言いたくなかったけど...        spohr_e38
# 23  RT @Eiichiro_Staff: さくらももこ先生ご逝去に際し、尾田さんより追悼イラス...     AltonoMilkit
# 24  RT @mollichane: さくらももこさんが亡くなって日が浅いので言いたくなかったけど...    nomin7500love
# 25  RT @shizuoka_cci: 「ちびまる子ちゃんを活用したまちづくり」\n２０１２年９...     shizuoka_cci
# 26  RT @mococo321: 「寝る前に嫌な事とか面倒な事を一切考えない。不眠症になるからね...   Christmas_1393
# 27  RT @mollichane: さくらももこさんが亡くなって日が浅いので言いたくなかったけど...       ichiro3219
# 28  RT @mollichane: さくらももこさんが亡くなって日が浅いので言いたくなかったけど...       htieknairb
# 29  RT @nekoneko_nyanko: さくらももこ先生、嫌われ者だった祖父の葬式を面白お...      necomamamsk
# ..                                                ...              ...
# 70  RT @hukushima_tomio: おはようございます！今日1日があなたにとって、とっ...      dorycoulson
# 71  RT @sakuyaoi: はてなブログに投稿しました！\n\nさくらももこ先生の足跡を辿る...         sakuyaoi
# 72  RT @mollichane: さくらももこさんが亡くなって日が浅いので言いたくなかったけど...    ori_pucchi123
# 73  RT @kubota_4_real: 同郷の天才が亡くなってしまった。若くして。\nあの時代...        mi_ko_cat
# 74  RT @sayoriNikki: 西原理恵子がさくらももこと似ているだなんて、流石にさくらも...        2616Sakai
# 75  RT @shukan_bunshun: 8月30日(木)発売の「#週刊文春」の目次を紹介。\...             NUCB
# 76  RT @mollichane: さくらももこさんが亡くなって日が浅いので言いたくなかったけど...        yamaza9ra
# 77  今朝の日経新聞にいしかわじゅん先生がさくらももこさんの追悼文を寄せている。「我々は何を失った...         simokita
# 78  RT @sobsin: さくらももこさん。ご冥福をお祈りいたします。 https://t.c...      wawawa_wako
# 79  RT @mollichane: さくらももこさんが亡くなって日が浅いので言いたくなかったけど...           syroha
# 80  RT @sobsin: さくらももこさん。ご冥福をお祈りいたします。 https://t.c...      sakuraxxx69
# 81  RT @mollichane: さくらももこさんが亡くなって日が浅いので言いたくなかったけど...          otk0330
# 82  RT @surugaya_kosin: 清水市出身でちびまる子ちゃんの作者、漫画家・さくらも...  surugayasizuoka
# 83  RT @hikaruland: 弊社のロゴマークを描いてくださった、さくらももこさんご逝去の...          asika43
# 84  RT @mollichane: これが書かれたのは東日本大震災の一週間後。さくらももこさんは...          sp_issa
# 85  RT @ODPEBM_sanseido: 【電子書籍】さくらももこ先生の『永沢君』図書館に行...   promo_sanseido
# 86  RT @hikaruland: さくらももこさんと親交が非常に深かった弊社 石井社長から、さ...          asika43
# 87  RT @Isseki3: ヘビースモーカーのさくらももこさんはタバコに殺された(乳癌の発症率...        kabuo_kun
# 88  RT @mollichane: さくらももこさんが亡くなって日が浅いので言いたくなかったけど...        szundokot
# 89  RT @mollichane: さくらももこさんが亡くなって日が浅いので言いたくなかったけど...          siou965
# 90  ゴシなう！ : 【驚愕】さくらももこさんの人生がガチですげえええええええええええええ htt...      misakicci_1
# 91  RT @mollichane: さくらももこさんが亡くなって日が浅いので言いたくなかったけど...     kotobukiya01
# 92  2年前、息子と二人で清水港の海鮮を食べた後に「ちびまる子ちゃんランド」へ行ったなぁ🙄\n\n...     masatani1969
# 93  RT @kaoruww: 流れでWikipediaを読んだが、さくらももこが初期の段階からア...        worry1203
# 94  RT @mollichane: さくらももこさんが亡くなって日が浅いので言いたくなかったけど...       Shino_suke
# 95  RT @supermomonga: 亡くなったさくらももこさんの作品が如何に素晴らしかったか...         watarin_
# 96  ありがとう！さくらももこさん | ヒカルランドブログ https://t.co/KTn4md...          asika43
# 97  RT @1123and0222: ちびまるこちゃんの原作者さくらももこさんの訃報が伝えられま...       princering
# 98  RT @nakamura326: 上京してすぐ人生最大の試練があって…その時に誰よりも助けて...     nyankorobe22
# 99  RT @mollichane: さくらももこさんが亡くなって日が浅いので言いたくなかったけど...         tany0324
#
#     strength  emotion
# 0   0.029418        5
# 1   0.148884        0
# 2   0.120147        4
# 3   0.120147        4
# 4   0.120147        4
# 5   0.071195        4
# 6   0.106272        4
# 7   0.265456        4
# 8   0.917076        0
# 9   0.120147        4
# 10  0.154256        4
# 11  0.249775        1
# 12  0.120147        4
# 13  0.120147        4
# 14  0.265456        4
# 15  0.235379        4
# 16  0.120147        4
# 17  0.187719        1
# 18  0.081102        4
# 19  0.432251        4
# 20  0.120147        4
# 21  0.120147        4
# 22  0.120147        4
# 23  0.249775        1
# 24  0.120147        4
# 25  0.236485        4
# 26  0.122284        4
# 27  0.120147        4
# 28  0.120147        4
# 29  0.122042        1
# ..       ...      ...
# 70  0.154256        4
# 71  0.467367        5
# 72  0.120147        4
# 73  0.423261        0
# 74  0.081102        4
# 75  0.247339        5
# 76  0.120147        4
# 77  0.140750        4
# 78  0.159871        4
# 79  0.120147        4
# 80  0.159871        4
# 81  0.120147        4
# 82  0.230829        1
# 83  0.065410        1
# 84  0.200612        4
# 85  0.040660        3
# 86  0.274415        0
# 87  0.106272        4
# 88  0.120147        4
# 89  0.120147        4
# 90  0.209596        5
# 91  0.120147        4
# 92  0.145047        4
# 93  0.110152        3
# 94  0.120147        4
# 95  0.177554        0
# 96  0.137802        0
# 97  0.181100        1
# 98  0.282932        3
# 99  0.120147        4
#
# [100 rows x 5 columns]
